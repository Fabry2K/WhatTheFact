# %% [markdown]
# # Fase 4 - Blind Matching su Kaggle (GPU)
#
# **Prima di eseguire:** Settings (pannello a destra) -> Accelerator: GPU T4 x2, Internet: On.
#
# **Input attesi** (aggiunti come Dataset da Add Input):
# - un file `.jsonl` con le assertion (Fase 2), es. `/kaggle/input/<dataset>/claims_with_questions.jsonl`
#
# **Secrets richiesti** (Add-ons -> Secrets): `TURSO_DATABASE_URL` e `TURSO_AUTH_TOKEN` — le fonti (scaricate dalla Fase 3) vivono nel database Turso, non serve piu' una cartella `sources/` come Dataset separato.
#
# Aggiorna il path nella cella 5 ("Esecuzione") in base al nome reale del tuo dataset.

# %% [markdown]
# ## 1. Verifica GPU disponibile

# %%
# !nvidia-smi
# Out:
# Tue Sep 22 16:22:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   55C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Installa e avvia Ollama
# Il modello viene scaricato una sola volta e resta nella cache della sessione.

# %%
# !apt-get update -qq && apt-get install -y zstd
# !apt-get install -y pciutils lshw
# !pip install libsql
# !curl -fsSL https://ollama.com/install.sh | sh

import subprocess, os, time, requests

# Il modello (qwen2.5:7b-instruct, ~5GB) sta comodamente su UNA sola T4 (15GB):
# OLLAMA_NUM_PARALLEL non lo spargerebbe mai su entrambe le GPU di sua iniziativa,
# lo fa solo se un modello non ci sta in una scheda sola. Per usare davvero
# entrambe le GPU servono due processi "ollama serve" separati, ciascuno pinnato
# a una GPU con CUDA_VISIBLE_DEVICES e su una porta diversa: lo script poi smista
# i documenti fra i due endpoint (vedi cella di esecuzione, --ollama-urls).
OLLAMA_INSTANCES = [
    {"gpu": "0", "port": 11434},
    {"gpu": "1", "port": 11435},
]
NUM_PARALLEL_PER_GPU = "4"  # per istanza; deve combaciare con --workers nella cella
                            # di esecuzione (--workers = NUM_PARALLEL_PER_GPU * n. GPU)

ollama_processes = []
for inst in OLLAMA_INSTANCES:
    env = os.environ.copy()
    env["CUDA_VISIBLE_DEVICES"] = inst["gpu"]
    env["OLLAMA_HOST"] = f"127.0.0.1:{inst['port']}"
    env["OLLAMA_NUM_PARALLEL"] = NUM_PARALLEL_PER_GPU

    log_path = f"/kaggle/working/ollama_gpu{inst['gpu']}.log"
    proc = subprocess.Popen(
        ["ollama", "serve"], env=env,
        stdout=open(log_path, "wb"), stderr=subprocess.STDOUT,
        preexec_fn=os.setsid,  # stacca il processo dal kernel: non muore se il kernel si riavvia
    )
    ollama_processes.append((inst, proc))
    print(f"Avviato ollama serve su GPU {inst['gpu']}, porta {inst['port']} (log: {log_path})")

for inst, proc in ollama_processes:
    for _ in range(30):
        try:
            requests.get(f"http://127.0.0.1:{inst['port']}")
            print(f"Ollama pronto su GPU {inst['gpu']} (porta {inst['port']})")
            break
        except requests.exceptions.ConnectionError:
            time.sleep(1)
    else:
        raise RuntimeError(f"Ollama su GPU {inst['gpu']} (porta {inst['port']}) non ha "
                            f"risposto in tempo, controlla /kaggle/working/ollama_gpu{inst['gpu']}.log")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 239 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (564 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 125186 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids usb.ids
# The following NEW packages will be installed:
#   libpci3 lshw pci.ids pciutils usb.ids
# 0 upgraded, 5 newly installed, 0 to remove and 239 not upgraded.
# Need to get 884 kB of archives.
# After this operation, 3,256 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 lshw amd64 02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1 [322 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb.ids all 2022.04.02-1 [219 kB]
# Fetched 884 kB in 1s (676 kB/s)
# Selecting previously unselected package pci.ids.
# (Reading database ... 125207 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2022.01.22-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package lshw.
# Preparing to unpack .../lshw_02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1_amd64.deb ...
# Unpacking lshw (02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Selecting previously unselected package usb.ids.
# Preparing to unpack .../usb.ids_2022.04.02-1_all.deb ...
# Unpacking usb.ids (2022.04.02-1) ...
# Setting up pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Setting up lshw (02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1) ...
# Setting up usb.ids (2022.04.02-1) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up pciutils (1:3.7.0-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%#####################                                     52.1%########################################               82.7%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Avviato ollama serve su GPU 0, porta 11434 (log: /kaggle/working/ollama_gpu0.log)
# Avviato ollama serve su GPU 1, porta 11435 (log: /kaggle/working/ollama_gpu1.log)
# Ollama pronto su GPU 0 (porta 11434)
# Ollama pronto su GPU 1 (porta 11435)

# %%
MODEL = "qwen2.5:7b-instruct"  # cambia qui se vuoi un modello diverso

import os, subprocess
for inst in OLLAMA_INSTANCES:
    print(f"Pull di {MODEL} su GPU {inst['gpu']} (porta {inst['port']})...")
    env = os.environ.copy()
    env["OLLAMA_HOST"] = f"127.0.0.1:{inst['port']}"
    subprocess.run(["ollama", "pull", MODEL], env=env, check=True)
# Out:
# Pull di qwen2.5:7b-instruct su GPU 0 (porta 11434)...
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest
# pulling 2bada8a74506:   0% ▕                  ▏  21 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   1% ▕                  ▏  56 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   3% ▕                  ▏ 143 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   5% ▕                  ▏ 227 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   6% ▕█                 ▏ 268 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   7% ▕█                 ▏ 351 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   9% ▕█                 ▏ 442 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:  10% ▕█                 ▏ 484 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:  12% ▕██                ▏ 566 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:  14% ▕██                ▏ 646 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:  15% ▕██                ▏ 687 MB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  16% ▕██                ▏ 768 MB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  18% ▕███               ▏ 855 MB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  19% ▕███               ▏ 892 MB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  21% ▕███               ▏ 974 MB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  23% ▕████              ▏ 1.1 GB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  24% ▕████              ▏ 1.1 GB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  25% ▕████              ▏ 1.2 GB/4.7 GB  685 MB/s      5spulling manifest
# pulling 2bada8a74506:  27% ▕████              ▏ 1.3 GB/4.7 GB  685 MB/s      4spulling manifest
# pulling 2bada8a74506:  28% ▕████              ▏ 1.3 GB/4.7 GB  685 MB/s      4spulling manifest
# pulling 2bada8a74506:  29% ▕█████             ▏ 1.4 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  31% ▕█████             ▏ 1.4 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  31% ▕█████             ▏ 1.5 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  33% ▕█████             ▏ 1.5 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  34% ▕██████            ▏ 1.6 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  35% ▕██████            ▏ 1.6 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  36% ▕██████            ▏ 1.7 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  38% ▕██████            ▏ 1.8 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  39% ▕██████            ▏ 1.8 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  40% ▕███████           ▏ 1.9 GB/4.7 GB  682 MB/s      4spulling manifest
# pulling 2bada8a74506:  41% ▕███████           ▏ 1.9 GB/4.7 GB  643 MB/s      4spulling manifest
# pulling 2bada8a74506:  42% ▕███████           ▏ 2.0 GB/4.7 GB  643 MB/s      4spulling manifest
# pulling 2bada8a74506:  43% ▕███████           ▏ 2.0 GB/4.7 GB  643 MB/s      4spulling manifest
# pulling 2bada8a74506:  45% ▕████████          ▏ 2.1 GB/4.7 GB  643 MB/s      4spulling manifest
# pulling 2bada8a74506:  45% ▕████████          ▏ 2.1 GB/4.7 GB  643 MB/s      3spulling manifest
# pulling 2bada8a74506:  47% ▕████████          ▏ 2.2 GB/4.7 GB  643 MB/s      3spulling manifest
# pulling 2bada8a74506:  48% ▕████████          ▏ 2.3 GB/4.7 GB  643 MB/s      3spulling manifest
# pulling 2bada8a74506:  49% ▕████████          ▏ 2.3 GB/4.7 GB  643 MB/s      3spulling manifest
# pulling 2bada8a74506:  51% ▕█████████         ▏ 2.4 GB/4.7 GB  643 MB/s      3spulling manifest
# pulling 2bada8a74506:  52% ▕█████████         ▏ 2.4 GB/4.7 GB  643 MB/s      3spulling manifest
# pulling 2bada8a74506:  53% ▕█████████         ▏ 2.5 GB/4.7 GB  643 MB/s      3spulling manifest
# pulling 2bada8a74506:  54% ▕█████████         ▏ 2.6 GB/4.7 GB  626 MB/s      3spulling manifest
# pulling 2bada8a74506:  56% ▕██████████        ▏ 2.6 GB/4.7 GB  626 MB/s      3spulling manifest
# pulling 2bada8a74506:  57% ▕██████████        ▏ 2.7 GB/4.7 GB  626 MB/s      3spulling manifest
# pulling 2bada8a74506:  59% ▕██████████        ▏ 2.8 GB/4.7 GB  626 MB/s      3spulling manifest
# pulling 2bada8a74506:  61% ▕██████████        ▏ 2.8 GB/4.7 GB  626 MB/s      2spulling manifest
# pulling 2bada8a74506:  61% ▕███████████       ▏ 2.9 GB/4.7 GB  626 MB/s      2spulling manifest
# pulling 2bada8a74506:  63% ▕███████████       ▏ 2.9 GB/4.7 GB  626 MB/s      2spulling manifest
# pulling 2bada8a74506:  65% ▕███████████       ▏ 3.0 GB/4.7 GB  626 MB/s      2spulling manifest
# pulling 2bada8a74506:  66% ▕███████████       ▏ 3.1 GB/4.7 GB  626 MB/s      2spulling manifest
# pulling 2bada8a74506:  67% ▕████████████      ▏ 3.2 GB/4.7 GB  626 MB/s      2spulling manifest
# pulling 2bada8a74506:  69% ▕████████████      ▏ 3.2 GB/4.7 GB  639 MB/s      2spulling manifest
# pulling 2bada8a74506:  70% ▕████████████      ▏ 3.3 GB/4.7 GB  639 MB/s      2spulling manifest
# pulling 2bada8a74506:  72% ▕████████████      ▏ 3.3 GB/4.7 GB  639 MB/s      2spulling manifest
# pulling 2bada8a74506:  73% ▕█████████████     ▏ 3.4 GB/4.7 GB  639 MB/s      1spulling manifest
# pulling 2bada8a74506:  74% ▕█████████████     ▏ 3.5 GB/4.7 GB  639 MB/s      1spulling manifest
# pulling 2bada8a74506:  76% ▕█████████████     ▏ 3.6 GB/4.7 GB  639 MB/s      1spulling manifest
# pulling 2bada8a74506:  78% ▕█████████████     ▏ 3.6 GB/4.7 GB  639 MB/s      1spulling manifest
# pulling 2bada8a74506:  78% ▕██████████████    ▏ 3.7 GB/4.7 GB  639 MB/s      1spulling manifest
# pulling 2bada8a74506:  80% ▕██████████████    ▏ 3.8 GB/4.7 GB  639 MB/s      1spulling manifest
# pulling 2bada8a74506:  82% ▕██████████████    ▏ 3.8 GB/4.7 GB  639 MB/s      1spulling manifest
# pulling 2bada8a74506:  83% ▕██████████████    ▏ 3.9 GB/4.7 GB  645 MB/s      1spulling manifest
# pulling 2bada8a74506:  84% ▕███████████████   ▏ 4.0 GB/4.7 GB  645 MB/s      1spulling manifest
# pulling 2bada8a74506:  86% ▕███████████████   ▏ 4.0 GB/4.7 GB  645 MB/s      1spulling manifest
# pulling 2bada8a74506:  87% ▕███████████████   ▏ 4.1 GB/4.7 GB  645 MB/s      0spulling manifest
# pulling 2bada8a74506:  89% ▕███████████████   ▏ 4.2 GB/4.7 GB  645 MB/s      0spulling manifest
# pulling 2bada8a74506:  90% ▕████████████████  ▏ 4.2 GB/4.7 GB  645 MB/s      0spulling manifest
# pulling 2bada8a74506:  90% ▕████████████████  ▏ 4.2 GB/4.7 GB  645 MB/s      0spulling manifest
# pulling 2bada8a74506:  91% ▕████████████████  ▏ 4.3 GB/4.7 GB  645 MB/s      0spulling manifest
# pulling 2bada8a74506:  92% ▕████████████████  ▏ 4.3 GB/4.7 GB  645 MB/s      0spulling manifest
# pulling 2bada8a74506:  92% ▕████████████████  ▏ 4.3 GB/4.7 GB  645 MB/s      0spulling manifest
# pulling 2bada8a74506:  92% ▕████████████████  ▏ 4.3 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  94% ▕████████████████  ▏ 4.4 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  94% ▕████████████████  ▏ 4.4 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  95% ▕█████████████████ ▏ 4.4 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  95% ▕█████████████████ ▏ 4.5 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  96% ▕█████████████████ ▏ 4.5 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  96% ▕█████████████████ ▏ 4.5 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  97% ▕█████████████████ ▏ 4.5 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  97% ▕█████████████████ ▏ 4.6 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  98% ▕█████████████████ ▏ 4.6 GB/4.7 GB  617 MB/s      0spulling manifest
# pulling 2bada8a74506:  99% ▕█████████████████ ▏ 4.6 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506:  99% ▕█████████████████ ▏ 4.6 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506:  99% ▕█████████████████ ▏ 4.6 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506:  99% ▕█████████████████ ▏ 4.7 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506: 100% ▕█████████████████ ▏ 4.7 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506: 100% ▕█████████████████ ▏ 4.7 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506: 100% ▕█████████████████ ▏ 4.7 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506: 100% ▕█████████████████ ▏ 4.7 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506: 100% ▕█████████████████ ▏ 4.7 GB/4.7 GB  576 MB/s      0spulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# verifying sha256 digest
# writing manifest
# success
# Pull di qwen2.5:7b-instruct su GPU 1 (porta 11435)...
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling 2f15b3218f05: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ## 3. Scrivi lo script su disco

# %%
# %%writefile /kaggle/working/4_blind_matching.py
#!/usr/bin/env python3
"""
Fase 4 (step "Interrogazione Articoli", con classificazione diretta):
per ogni claim, legge le assertion prodotte dalla Fase 2 (JSONL) e le fonti
scaricate dalla Fase 3 (database Turso/libSQL, tabelle sources + claim_source_links),
e per ogni coppia (assertion, articolo) chiede a un LLM locale via Ollama di
classificare l'esito leggendo SOLO il testo dell'articolo.

Selezione dei documenti (--mapping, default "pooled"): tutti i documenti scaricati
per un claim finiscono in un pool unico, deduplicato per URL, e ogni domanda viene
interrogata sui più pertinenti per sovrapposizione lessicale. Le query di uno stesso
claim cercano tutte la stessa storia, quindi l'articolo che risponde alla domanda 3 è
spesso fra i risultati della query 1: legare rigidamente la domanda N ai soli
risultati della query N (--mapping strict, il comportamento storico) faceva perdere
quelle corrispondenze e produceva "Non verificabile" su fonti già scaricate.
La provenienza resta tracciata in "retrieved_by_query_index".

Metodologia di verifica (blind matching in due passi separati):
non si chiede al modello di classificare direttamente l'"assertion" originale
(rischio di bias/leading, e la formulazione dell'assertion appartiene all'articolo
di partenza, non a quello candidato). Si procede invece con DUE chiamate distinte:

  1. LETTURA CIECA — il modello riceve solo la "question" e il testo dell'articolo
     candidato, e ne estrae la risposta con una citazione verbatim. La "answer" di
     riferimento NON è nel prompt.
  2. CONFRONTO — il modello riceve la domanda, la risposta appena estratta e la
     "answer" di riferimento (mai l'articolo), e classifica l'esito.

La separazione non è cosmetica: con i due passi fusi in un unico prompt il modello
aveva la risposta attesa davanti mentre "leggeva" e finiva per restituirla come
citazione dell'articolo candidato, rendendo l'esito "Concorda" privo di valore.
Tenendo la risposta di riferimento fuori dal prompt di lettura, la contaminazione
diventa strutturalmente impossibile.

Output: per ogni claim, un file <output-dir>/<claim_id>.jsonl con una riga JSON per
ogni risultato di matching (uno per articolo effettivamente scaricato), scritta e
flushata su disco subito dopo essere stata calcolata — puoi quindi seguire l'avanzamento
in tempo reale con `tail -f matching_results/<claim_id>.jsonl`.

Prerequisiti:
    1) Ollama installato e in esecuzione (https://ollama.com)
    2) Modello scaricato: ollama pull qwen2.5:7b-instruct
    3) pip install requests libsql
    4) Un database Turso (stesso usato dalla Fase 3, vedi download_sources.py)

Uso:
    python blind_matching.py --questions claims_with_questions.jsonl \
        --output-dir matching_results
    (URL/token Turso da --turso-url/--turso-token oppure da env var
    TURSO_DATABASE_URL/TURSO_AUTH_TOKEN)
"""

import argparse
import concurrent.futures
import json
import os
import re
import sys
import time
import zlib
import requests

try:
    import libsql
except ImportError:
    print("ERRORE: manca il pacchetto 'libsql'. Installa con: pip install libsql", file=sys.stderr)
    sys.exit(1)

OLLAMA_URL = "http://localhost:11434/api/chat"
DEFAULT_MODEL = "qwen2.5:7b-instruct"
DB_MAX_RETRIES = 4  # tentativi per ogni operazione sul DB Turso: c'e' sempre una
                     # richiesta HTTP di mezzo, un blip di rete non deve far
                     # fallire l'intero claim
DEFAULT_KEEP_ALIVE = "30m"  # tiene il modello caricato fra una chiamata e l'altra
                             # (default Ollama: 5m -> ricarica il modello da zero se
                             # passano piu' di 5 minuti fra due chiamate, es. per delay
                             # o download lenti fra un claim e l'altro)
DEFAULT_WORKERS = 4  # chiamate concorrenti a Ollama; combacia col default server-side
                      # di OLLAMA_NUM_PARALLEL nelle versioni recenti. Su CPU (anziche'
                      # GPU) il guadagno da parallelizzare puo' essere marginale o nullo:
                      # se non noti differenze rispetto a --workers 1, il collo di
                      # bottiglia e' il calcolo, non la concorrenza di rete.

def normalize_keep_alive(value):
    """Ollama vuole un numero (secondi, o -1 per 'sempre') oppure una stringa
    di durata CON unita' (es. "30m"). Una stringa puramente numerica come "-1"
    o "300" (quella che arriva da --keep-alive via CLI) va convertita in int,
    altrimenti Ollama la rifiuta con 400 ("missing unit in duration")."""
    if isinstance(value, str) and re.fullmatch(r"-?\d+", value):
        return int(value)
    return value

# sessione HTTP condivisa: riusa la connessione TCP/keep-alive verso Ollama invece
# di aprirne una nuova a ogni requests.post()
_SESSION = requests.Session()
# pool piu' ampio del default (10): con --workers > 10 servono piu' connessioni
# aperte in parallelo verso Ollama, altrimenti requests le mette comunque in coda
_adapter = requests.adapters.HTTPAdapter(pool_connections=20, pool_maxsize=20)
_SESSION.mount("http://", _adapter)
_SESSION.mount("https://", _adapter)

MAX_ARTICLE_CHARS = 12000  # limite prudente per il contesto di un modello 7B (con num_ctx=8192 sotto)
DEFAULT_DOCS_PER_QUESTION = 5
DEFAULT_MIN_CONTENT_CHARS = 500  # sotto questa soglia e' quasi sempre uno snippet, non un articolo

VALID_ESITI = {"Concorda", "Contraddice", "Parzialmente concorda", "Non verificabile"}

# mappa forme normalizzate (minuscolo, senza spazi extra) -> etichetta canonica,
# per tollerare variazioni di maiuscole/minuscole o piccola difformita' nel testo
# che il modello potrebbe restituire nonostante le istruzioni
_ESITO_NORMALIZED = {re.sub(r"\s+", " ", e.strip().lower()): e for e in VALID_ESITI}


def normalize_esito(value):
    if not isinstance(value, str):
        return None
    key = re.sub(r"\s+", " ", value.strip().lower())
    return _ESITO_NORMALIZED.get(key)

SYSTEM_PROMPT_READ = """Sei un lettore di articoli.

Rispondi alla DOMANDA interrogando con quella, l'ARTICOLO. Non usare conoscenze esterne.

Usa null per entrambi SOLO se l'articolo non tratta affatto l'argomento della domanda.
Non confondere una semplice menzione di una persona/argomento con una risposta.

Esempio:
DOMANDA: "Quanti posti di lavoro ha creato la legge?"
ARTICOLO: "...la legge, secondo l'ufficio bilancio, dovrebbe generare circa 40.000 posti entro il 2025..."
{"risposta_articolo": "circa 40.000 posti entro il 2025", "evidenza": "dovrebbe generare circa 40.000 posti entro il 2025"}


Restituisci esclusivamente questo JSON:
{"risposta_articolo": "...", "evidenza": "..."}

"risposta_articolo" deve contenere la risposta alla domanda, anche se parziale.
"evidenza" deve essere una citazione breve, esatta e verbatim della porzione dell'articolo che risponde alla domanda. Se la risposta è null, anche "evidenza" deve essere null.
"""


SYSTEM_PROMPT_COMPARE = """Confronta RISPOSTA A e RISPOSTA B rispetto alla DOMANDA.

A proviene da un articolo trovato indipendentemente. B è la risposta di riferimento e rappresenta ciò che sostiene l'articolo originale, non necessariamente la verità.

Valuta il significato, non le parole o il livello di dettaglio.

Classifica il rapporto come:

* "Concorda": A e B esprimono la stessa informazione. A può essere più dettagliata o precisa.
* "Contraddice": A e B esprimono valori incompatibili sullo stesso fatto.
* "Parzialmente concorda": A riguarda lo stesso fatto, ma ne riporta solo una parte o omette dettagli rilevanti.
* "Non verificabile": A non contiene informazioni pertinenti alla domanda.

Una differenza di dettaglio non è una contraddizione. Se A e B possono essere vere entrambe, non scegliere "Contraddice".

Rispondi esclusivamente con:
{"esito": "...", "motivazione": "..."}
"""


def sanitize_folder_name(value) -> str:
    name = str(value).strip()
    name = re.sub(r"[^\w\-.]", "_", name)
    return name or "unknown_id"


def load_assertions(questions_path: str) -> dict:
    """Carica il JSONL di Fase 2 e restituisce {claim_id: [assertion_dict, ...]}."""
    claims = {}
    with open(questions_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            claim_id = str(record.get("id"))
            claims[claim_id] = {
                # in modalità claim il record non ha "title": si mostra il claim stesso
                "title": record.get("title") or record.get("claim", ""),
                "label": record.get("label"),
                "assertions": record.get("questions", []),
            }
    return claims


def _db_call(fn, *args, **kwargs):
    """Esegue una chiamata al DB sotto retry, per errori di rete transitori
    (a differenza di un file locale, qui c'e' sempre una richiesta HTTP di mezzo)."""
    last_err = None
    for attempt in range(1, DB_MAX_RETRIES + 1):
        try:
            return fn(*args, **kwargs)
        except Exception as e:
            last_err = e
            print(f"    [DB retry {attempt}/{DB_MAX_RETRIES}] {e}", file=sys.stderr)
            time.sleep(1.5 * attempt)
    raise RuntimeError(f"operazione sul DB Turso fallita dopo {DB_MAX_RETRIES} tentativi: {last_err}")


def open_turso(turso_url: str, turso_token: str):
    return libsql.connect(database=turso_url, auth_token=turso_token)


def fetch_claim_rows(conn, claim_id) -> list:
    """Righe (url, query, query_index, title, body_compresso, insufficient_content)
    per un claim, via JOIN fra claim_source_links e sources. La deduplica per URL
    e' gia' garantita dallo schema (PRIMARY KEY (claim_id, url) in
    claim_source_links, scritta cosi' dalla Fase 3): non serve rifarla qui."""
    def _run():
        cur = conn.execute(
            "SELECT csl.url, csl.query, csl.query_index, s.title, s.body, "
            "s.insufficient_content "
            "FROM claim_source_links csl JOIN sources s ON csl.url = s.url "
            "WHERE csl.claim_id = ?",
            (str(claim_id),),
        )
        return cur.fetchall()

    return _db_call(_run)


def _ollama_json(system_prompt: str, user_content: str, model: str, ollama_url: str,
                  required_field: str, max_retries: int = 3, timeout: int = 300,
                  num_predict: int = 600, keep_alive: str = DEFAULT_KEEP_ALIVE) -> dict:
    """Una chiamata a Ollama in modalita' chat con output JSON forzato, con retry.
    Solleva RuntimeError se dopo tutti i tentativi non arriva un JSON valido che
    contenga `required_field`."""
    last_err = None
    for attempt in range(1, max_retries + 1):
        # con temperature=0 un errore di JSON malformato (es. virgolette non
        # escapate copiate verbatim dall'articolo) e' completamente deterministico:
        # riprovare con gli stessi parametri rigenera byte-per-byte lo stesso output
        # rotto. Dal secondo tentativo in poi alziamo leggermente la temperature
        # per dare al modello una reale possibilita' di uscire da quello stato.
        temperature = 0 if attempt == 1 else 0.4
        payload = {
            "model": model,
            "messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_content},
            ],
            "format": "json",
            "stream": False,
            "keep_alive": normalize_keep_alive(keep_alive),
            "options": {"temperature": temperature, "num_predict": num_predict, "num_ctx": 8192},
        }
        try:
            resp = _SESSION.post(ollama_url, json=payload, timeout=timeout)
            resp.raise_for_status()
            content = resp.json().get("message", {}).get("content", "")

            try:
                parsed = json.loads(content)
            except json.JSONDecodeError:
                # fallback: prova a isolare il blocco {...} piu' esterno, nel caso
                # ci siano caratteri residui prima/dopo (raro con format=json, ma capita
                # con output troncati)
                start, end = content.find("{"), content.rfind("}")
                if start == -1 or end == -1 or end <= start:
                    raise
                parsed = json.loads(content[start:end + 1])

            if required_field not in parsed:
                raise ValueError(f"campo '{required_field}' assente nella risposta del modello")
            return parsed
        except (requests.RequestException, json.JSONDecodeError, ValueError, KeyError,
                AttributeError, TypeError) as e:
            last_err = str(e)
            print(f"    [retry {attempt}/{max_retries}] chiamata Ollama fallita: {last_err}", file=sys.stderr)
            time.sleep(1.5 * attempt)

    raise RuntimeError(f"risposta LLM non valida dopo {max_retries} tentativi: {last_err}")


def call_ollama(question_text: str, reference_answer: str, article_text: str, model: str, ollama_url: str,
                 max_retries: int = 3, timeout: int = 300, keep_alive: str = DEFAULT_KEEP_ALIVE) -> dict:
    """Blind matching in DUE chiamate separate, come previsto dall'assignment.

    PASSO 1 (lettura cieca): il modello riceve la domanda e l'articolo candidato, e
    NON vede la risposta di riferimento. Questo e' il punto: quando i due passi
    stavano in un unico prompt, il modello aveva la risposta attesa sotto gli occhi
    mentre "leggeva" e finiva per ricopiarla come se l'avesse trovata nell'articolo
    — nei test la citazione restituita era letteralmente la risposta di riferimento,
    e l'esito "Concorda" era quindi privo di valore. Separando le chiamate la
    contaminazione diventa strutturalmente impossibile: quel testo non e' nel prompt.

    PASSO 2 (confronto): il modello riceve solo la domanda, la risposta estratta al
    passo 1 e la risposta di riferimento — non l'articolo. E' un compito piccolo e
    ben delimitato, molto piu' alla portata di un modello 7B rispetto al prompt unico
    che chiedeva lettura, estrazione, citazione verbatim e classificazione insieme.
    """
    try:
        read = _ollama_json(
            SYSTEM_PROMPT_READ,
            f"DOMANDA:\n{question_text}\n\n"
            f"TESTO ARTICOLO CANDIDATO:\n{article_text[:MAX_ARTICLE_CHARS]}\n\n"
            f"Rispondi con il JSON richiesto.",
            model=model, ollama_url=ollama_url, required_field="risposta_articolo",
            max_retries=max_retries, timeout=timeout, keep_alive=keep_alive,
        )
    except RuntimeError as e:
        print(f"    [WARN] passo di lettura fallito: {e}", file=sys.stderr)
        return {"risposta_articolo": None, "esito": "Non verificabile", "evidenza": None,
                "motivazione": f"[ERRORE] {e}"}

    risposta_articolo = read.get("risposta_articolo")
    evidenza = read.get("evidenza")
    if isinstance(risposta_articolo, str) and not risposta_articolo.strip():
        risposta_articolo = None

    # se l'articolo non parla dell'argomento non c'e' nulla da confrontare:
    # risparmiamo la seconda chiamata
    if not risposta_articolo:
        return {"risposta_articolo": None, "esito": "Non verificabile", "evidenza": None,
                "motivazione": "l'articolo candidato non tratta l'argomento della domanda"}

    try:
        compare = _ollama_json(
            SYSTEM_PROMPT_COMPARE,
            f"DOMANDA:\n{question_text}\n\n"
            f"RISPOSTA A (estratta dall'articolo candidato):\n{risposta_articolo}\n\n"
            f"RISPOSTA B (di riferimento, secondo l'articolo originale sotto verifica):\n{reference_answer}\n\n"
            f"Rispondi con il JSON richiesto.",
            model=model, ollama_url=ollama_url, required_field="esito",
            max_retries=max_retries, timeout=timeout, num_predict=300, keep_alive=keep_alive,
        )
    except RuntimeError as e:
        print(f"    [WARN] passo di confronto fallito: {e}", file=sys.stderr)
        return {"risposta_articolo": risposta_articolo, "esito": "Non verificabile",
                "evidenza": evidenza, "motivazione": f"[ERRORE] {e}"}

    esito = normalize_esito(compare.get("esito"))
    if esito is None:
        print(f"    [WARN] esito non riconosciuto: {compare.get('esito')!r}", file=sys.stderr)
        esito = "Non verificabile"

    return {
        "risposta_articolo": risposta_articolo,
        "esito": esito,
        "evidenza": evidenza,
        "motivazione": compare.get("motivazione", ""),
    }


_QUOTE_CHARS = str.maketrans({
    "‘": "'", "’": "'", "“": '"', "”": '"', "'": "'", '"': '"',
})


def _strip_citation_noise(evidenza: str) -> str:
    """Ripulisce la citazione dai residui di sintassi JSON che il modello a volte
    lascia dentro il valore: virgolette di incapsulamento e la virgola finale del
    campo. Senza questo, una citazione corretta risulta "non verificata" solo per
    un carattere di troppo ai bordi."""
    return (evidenza or "").strip().strip(",").strip().strip("\"“”'‘’").strip()


def _normalize_for_evidence_check(text: str) -> str:
    """Normalizza spazi e varianti tipografiche di virgolette (dritte/curve,
    singole/doppie) a una forma comune, cosi' il confronto verbatim non fallisce
    solo perche' il modello ha scelto uno stile di virgolette diverso da quello
    dell'articolo originale (es. per evitare di rompere il JSON, vedi SYSTEM_PROMPT)."""
    text = text.translate(_QUOTE_CHARS)
    text = re.sub(r"[\"']", "", text)
    return re.sub(r"\s+", " ", text).strip()


def check_evidence(evidenza, article_text: str) -> bool:
    """Verifica (anti-hallucination) che la citazione sia effettivamente presente
    nel testo dell'articolo, in modo esatto o con normalizzazione minima degli spazi
    e delle virgolette."""
    if not evidenza:
        return False
    normalized_article = _normalize_for_evidence_check(article_text)
    normalized_evidence = _normalize_for_evidence_check(_strip_citation_noise(evidenza))
    if not normalized_evidence:
        return False
    return normalized_evidence in normalized_article


# ---------------------------------------------------------------------------
# Selezione dei documenti da interrogare
#
# La Fase 3 scarica N risultati per OGNI query, e la versione precedente di questo
# script interrogava la domanda i-esima solo sui documenti recuperati dalla query
# i-esima. E' una perdita di recall notevole: le query di uno stesso claim cercano
# tutte la stessa storia, e l'articolo che risponde alla domanda 3 e' spesso fra i
# risultati della query 1 (tipicamente la cronaca completa dell'evento, che copre
# tutti i fatti). Con quel vincolo rigido quella domanda non lo vedeva mai e
# l'esito era "Non verificabile" pur avendo la fonte gia' scaricata.
#
# Qui i documenti del claim finiscono in un pool unico, deduplicato per URL, e ogni
# domanda viene confrontata con i piu' pertinenti per sovrapposizione lessicale.
# ---------------------------------------------------------------------------

_DOC_TOKEN_RE = re.compile(r"\$?\d[\d.,/]*%?|[A-Za-z][A-Za-z'’-]*")

_DOC_STOPWORDS = {
    "a", "an", "and", "are", "as", "at", "be", "been", "but", "by", "did", "do", "does",
    "for", "from", "had", "has", "have", "he", "her", "his", "how", "in", "into", "is",
    "it", "its", "of", "on", "or", "said", "say", "says", "she", "that", "the", "their",
    "them", "they", "this", "to", "was", "were", "what", "when", "where", "which", "who",
    "why", "will", "with", "would", "about", "according", "over", "under", "than", "there",
    "these", "those", "much", "many", "some", "any", "not", "no", "yes", "source", "report",
}


def _doc_tokens(text: str) -> list:
    return [t.strip(".,;:!?'’-").lower() for t in _DOC_TOKEN_RE.findall(text or "")]


def _is_specific(token: str) -> bool:
    """Numeri, importi e parole lunghe pesano di piu': sono i termini che davvero
    distinguono un articolo sullo stesso fatto da uno sullo stesso tema."""
    stripped = token.lstrip("$")
    return (bool(stripped) and stripped[0].isdigit()) or len(token) > 7


_MD_IMAGE_RE = re.compile(r"!\[[^\]]*\]\([^)]*\)")
_MD_LINK_RE = re.compile(r"\[([^\]]*)\]\([^)]*\)")
_BARE_URL_RE = re.compile(r"https?://\S+")


def clean_article_text(text: str) -> str:
    """Toglie il contorno di navigazione dal testo estratto dalla pagina.

    Il contenuto che arriva da Tavily/trafilatura conserva spesso, prima
    dell'articolo vero, un blocco di menu, loghi e link social in sintassi
    markdown. Su un modello 7B quel rumore compete con il testo utile: nei test
    l'articolo giusto veniva dichiarato "non pertinente" pur contenendo la frase
    cercata poche righe piu' sotto. Qui si rimuovono immagini, URL e voci di menu,
    conservando il testo dei link (che spesso e' contenuto legittimo)."""
    if not text:
        return ""

    text = _MD_IMAGE_RE.sub(" ", text)
    text = _MD_LINK_RE.sub(r"\1", text)
    text = _BARE_URL_RE.sub(" ", text)

    kept = []
    for line in text.splitlines():
        stripped = line.strip()
        if not stripped:
            kept.append("")
            continue
        # voci di menu: riga di elenco molto corta, tipicamente una sola etichetta
        bullet = stripped.lstrip("*-•").strip()
        if stripped.startswith(("*", "-", "•")) and len(bullet.split()) <= 4:
            continue
        if len(stripped) <= 2:
            continue
        kept.append(stripped)

    cleaned = "\n".join(kept)
    cleaned = re.sub(r"\n{3,}", "\n\n", cleaned)
    return re.sub(r"[ \t]{2,}", " ", cleaned).strip()


def load_claim_documents(turso_url, turso_token, claim_id, min_content_chars):
    conn = open_turso(turso_url, turso_token)
    rows = fetch_claim_rows(conn, claim_id)
    documents = []
    skipped_short = 0

    for url, query, query_index, title, body_blob, insufficient_content in rows:
        if insufficient_content:
            skipped_short += 1
            continue
        try:
            raw_body = zlib.decompress(body_blob).decode("utf-8") if body_blob else ""
        except (zlib.error, UnicodeDecodeError) as e:
            print(f"  [WARN] body illeggibile per {url}: {e}, salto")
            skipped_short += 1
            continue

        body = clean_article_text(raw_body)
        if len(body) < min_content_chars:
            skipped_short += 1
            continue

        documents.append({
            "url": url,
            "title": title or "",
            "query": query or "",
            "query_index": query_index,
            "body": body,
            "tokens": set(_doc_tokens(body[:MAX_ARTICLE_CHARS])),
        })

    if skipped_short:
        print(f"  [INFO] {skipped_short} documenti scartati perche' senza contenuto "
              f"sufficiente (< {min_content_chars} caratteri)")
    return documents


def score_document(document: dict, assertion: dict) -> float:
    """Quanto un documento e' promettente per QUESTA domanda: quota dei termini di
    domanda+risposta che compaiono nel testo, con peso maggiore a numeri e parole
    lunghe (i termini realmente discriminanti)."""
    needle = " ".join([
        assertion.get("question", ""), assertion.get("answer", ""), assertion.get("assertion", ""),
    ])
    terms = {t for t in _doc_tokens(needle) if t and t not in _DOC_STOPWORDS and len(t) > 2}
    if not terms:
        return 0.0

    total = matched = 0.0
    for term in terms:
        weight = 3.0 if _is_specific(term) else 1.0
        total += weight
        if term in document["tokens"]:
            matched += weight
    return matched / total if total else 0.0


def select_documents_for_assertion(documents: list, assertion: dict, assertion_index: int,
                                    max_docs: int, mapping: str) -> list:
    """Restituisce [(score, documento)] per la domanda data.

    - mapping="strict": comportamento storico, solo i documenti recuperati dalla
      query con lo stesso indice della domanda.
    - mapping="pooled": tutti i documenti del claim, ordinati per rilevanza. I
      documenti cercati proprio per questa domanda restano comunque prioritari a
      parita' di punteggio, cosi' la provenienza della ricerca continua a contare.
    """
    if mapping == "strict":
        own = [d for d in documents if d.get("query_index") == assertion_index]
        return [(score_document(d, assertion), d) for d in own][:max_docs]

    scored = [
        (score_document(d, assertion), 0 if d.get("query_index") == assertion_index else 1, d)
        for d in documents
    ]
    scored.sort(key=lambda item: (-item[0], item[1]))
    return [(score, document) for score, _, document in scored[:max_docs]]


def process_claim(turso_url, turso_token, claim_id: str, claim_data: dict, output_dir: str,
                   model: str, ollama_urls: list, delay: float, skip_existing: bool, timeout: int,
                   docs_per_question: int = DEFAULT_DOCS_PER_QUESTION, mapping: str = "pooled",
                   min_content_chars: int = DEFAULT_MIN_CONTENT_CHARS,
                   keep_alive: str = DEFAULT_KEEP_ALIVE, workers: int = DEFAULT_WORKERS):
    folder_name = sanitize_folder_name(claim_id)
    output_path = os.path.join(output_dir, f"{folder_name}.jsonl")

    expected_rows = len(claim_data["assertions"]) * docs_per_question
    if skip_existing and os.path.exists(output_path):
        with open(output_path, "r", encoding="utf-8") as f:
            existing_lines = sum(1 for line in f if line.strip())
        if existing_lines >= expected_rows:
            print(f"  -> risultato gia' completo ({output_path}, {existing_lines} righe), salto")
            return
        print(f"  -> trovato output incompleto ({existing_lines}/{expected_rows} righe), riprocesso il claim da capo")

    assertions = claim_data["assertions"]
    n_saved = 0

    documents = load_claim_documents(turso_url, turso_token, claim_id, min_content_chars=min_content_chars)
    if not documents:
        print(f"  [WARN] nessun documento utilizzabile per il claim {claim_id} nel DB, salto")
        return
    print(f"  {len(documents)} documenti utilizzabili nel pool del claim")

    os.makedirs(output_dir, exist_ok=True)
    with open(output_path, "w", encoding="utf-8") as out_f:
        for assertion_index, assertion in enumerate(assertions, start=1):
            assertion_text = assertion.get("assertion", "")
            # la domanda da porre all'articolo candidato e la risposta di riferimento
            # (secondo l'articolo originale) prodotte in Fase 2. Se per qualche voce
            # mancassero (dati vecchi generati prima di questa modifica), ripieghiamo
            # sull'assertion stessa per non bloccare il pipeline.
            question_text = assertion.get("question") or assertion_text
            reference_answer = assertion.get("answer") or assertion_text

            selected = select_documents_for_assertion(
                documents, assertion, assertion_index,
                max_docs=docs_per_question, mapping=mapping,
            )
            print(f"  domanda #{assertion_index} ({question_text[:60]}...): "
                  f"{len(selected)} documenti selezionati")

            # le chiamate ai documenti di questa domanda sono indipendenti fra loro
            # (stesso model/prompt, articoli diversi), quindi si sottomettono tutte
            # insieme al pool e si raccolgono i risultati NELL'ORDINE ORIGINALE
            # (non nell'ordine di completamento): la scrittura su disco resta
            # deterministica e identica a prima, solo le chiamate diventano concorrenti.
            # Con --workers 1 il comportamento e' identico alla versione sequenziale.
            #
            # Con piu' di un endpoint Ollama (una GPU ciascuno) i documenti vengono
            # smistati a rotazione fra tutti gli endpoint: il modello sta comodamente
            # su una sola T4 (15GB), quindi Ollama non lo spargerebbe mai da solo su
            # entrambe le GPU — l'unico modo per usarle davvero entrambe e' avere due
            # processi server separati e distribuire le chiamate fra i due.
            with concurrent.futures.ThreadPoolExecutor(max_workers=max(1, workers)) as executor:
                futures = [
                    executor.submit(
                        call_ollama, question_text, reference_answer, document["body"],
                        model=model, ollama_url=ollama_urls[idx % len(ollama_urls)],
                        timeout=timeout, keep_alive=keep_alive,
                    )
                    for idx, (_score, document) in enumerate(selected)
                ]

                for rank, ((score, document), future) in enumerate(zip(selected, futures), start=1):
                    verdict = future.result()
                    print(f"    [{rank}/{len(selected)}] {document['url'][:60]} "
                          f"(rilevanza {score:.2f}) {document['title'][:50]}")
                    evidenza_verificata = check_evidence(verdict["evidenza"], document["body"])
                    if verdict["evidenza"] and not evidenza_verificata:
                        print(f"      [WARN] evidenza restituita dal modello NON trovata verbatim nel testo "
                              f"(possibile hallucination)")

                    # "Non verificabile" significa che l'articolo non tratta l'argomento:
                    # se pero' il modello e' riuscito a estrarne una risposta, le due cose
                    # si contraddicono. Non riscriviamo il suo giudizio, ma lo segnaliamo:
                    # in Fase 5 una riga cosi' non va contata come "fonte che tace".
                    esito_incoerente = (
                        verdict["esito"] == "Non verificabile" and bool(verdict["risposta_articolo"])
                    )
                    if esito_incoerente:
                        print(f"      [WARN] esito 'Non verificabile' ma il modello ha comunque "
                              f"estratto una risposta dall'articolo")

                    result = {
                        "claim_id": claim_id,
                        "assertion_index": assertion_index,
                        "assertion": assertion_text,
                        "question": question_text,
                        "reference_answer": reference_answer,
                        "centrality": assertion.get("centrality"),
                        "provenance": assertion.get("provenance"),
                        "source_url": document["url"],
                        "source_title": document["title"],
                        # query che ha effettivamente recuperato questo documento: con il
                        # pooling puo' essere diversa da quella della domanda in esame,
                        # quindi la tracciabilita' richiesta dall'assignment ("sai perche'
                        # una fonte e' stata cercata") viene tenuta esplicita qui
                        "source_query": document["query"],
                        "retrieved_by_query_index": document["query_index"],
                        "selected_by": mapping,
                        "selection_rank": rank,
                        "relevance_score": round(score, 4),
                        "risposta_articolo": verdict["risposta_articolo"],
                        "esito": verdict["esito"],
                        "evidenza": verdict["evidenza"],
                        "evidenza_verificata": evidenza_verificata,
                        "esito_incoerente": esito_incoerente,
                        "motivazione": verdict["motivazione"],
                    }

                    print(f"      -> {result['esito']}"
                          + (" [evidenza NON verificata]" if verdict["evidenza"] and not evidenza_verificata else ""))

                    out_f.write(json.dumps(result, ensure_ascii=False) + "\n")
                    out_f.flush()
                    os.fsync(out_f.fileno())
                    n_saved += 1

            # con chiamate concorrenti un delay per-documento non avrebbe senso (i
            # documenti partono gia' tutti insieme): il delay si applica una volta
            # per domanda, fra un gruppo di chiamate concorrenti e il successivo
            if delay > 0:
                time.sleep(delay)

    print(f"  -> {n_saved} matching salvati in {output_path}")


def build_rollup(output_dir: str, claims: dict, claim_ids: list, rollup_path: str) -> int:
    """Raccoglie i risultati per-fonte in una riga per claim.

    E' una pura riorganizzazione: conta gli esiti, non li combina. Il verdetto unico
    per claim richiede di decidere come pesare centralita', affidabilita' della fonte
    e fonti in conflitto — sono le scelte che spettano alla Fase 5, e anticiparle qui
    significherebbe deciderle di fatto senza averle discusse. Qui si prepara solo il
    materiale su cui quella formula lavorera', con `claim_id` pronto per il join con
    le label di riferimento quando saranno disponibili.

    I risultati vengono riletti da disco, non accumulati durante l'esecuzione, cosi'
    il riepilogo comprende anche i claim gia' processati in run precedenti e saltati
    da --skip-existing."""
    rows = 0
    with open(rollup_path, "w", encoding="utf-8") as out_f:
        for claim_id in claim_ids:
            claim_data = claims[claim_id]
            results_path = os.path.join(output_dir, f"{sanitize_folder_name(claim_id)}.jsonl")
            if not os.path.exists(results_path):
                continue

            with open(results_path, "r", encoding="utf-8") as f:
                results = [json.loads(line) for line in f if line.strip()]
            if not results:
                continue

            per_question = {}
            for result in results:
                index = result.get("assertion_index")
                entry = per_question.setdefault(index, {
                    "assertion_index": index,
                    "question": result.get("question", ""),
                    "reference_answer": result.get("reference_answer", ""),
                    "centrality": result.get("centrality"),
                    "n_fonti": 0,
                    "esiti": {},
                    "evidenze_verificate": 0,
                    "esiti_incoerenti": 0,
                })
                esito = result.get("esito")
                entry["n_fonti"] += 1
                entry["esiti"][esito] = entry["esiti"].get(esito, 0) + 1
                entry["evidenze_verificate"] += bool(result.get("evidenza_verificata"))
                entry["esiti_incoerenti"] += bool(result.get("esito_incoerente"))

            totali = {}
            for entry in per_question.values():
                for esito, n in entry["esiti"].items():
                    totali[esito] = totali.get(esito, 0) + n

            record = {
                "claim_id": claim_id,
                "claim": claim_data.get("title", ""),
                # presente solo se il dataset di partenza porta gia' una label
                "label": claim_data.get("label"),
                "n_domande": len(per_question),
                "n_fonti_totali": len(results),
                "esiti_totali": totali,
                "domande": [per_question[k] for k in sorted(per_question, key=lambda x: (x is None, x))],
            }
            out_f.write(json.dumps(record, ensure_ascii=False) + "\n")
            rows += 1
    return rows


def main():
    parser = argparse.ArgumentParser(description=__doc__, formatter_class=argparse.RawDescriptionHelpFormatter)
    parser.add_argument("--questions", required=True, help="Path al JSONL prodotto dalla Fase 2 (con campo 'questions'/assertion)")
    parser.add_argument("--turso-url", default=os.environ.get("TURSO_DATABASE_URL"),
                         help="URL del database Turso con le fonti scaricate dalla Fase 3 "
                              "(es. libsql://il-tuo-db.turso.io). Default: legge da env var "
                              "TURSO_DATABASE_URL.")
    parser.add_argument("--turso-token", default=os.environ.get("TURSO_AUTH_TOKEN"),
                         help="Auth token del database Turso. Default: legge da env var TURSO_AUTH_TOKEN.")
    parser.add_argument("--output-dir", default="matching_results", help="Cartella dove salvare i risultati del matching (default: matching_results)")
    parser.add_argument("--model", default=DEFAULT_MODEL, help=f"Nome del modello Ollama da usare (default: {DEFAULT_MODEL})")
    parser.add_argument("--ollama-url", default=OLLAMA_URL, help=f"URL dell'endpoint chat di Ollama (default: {OLLAMA_URL})")
    parser.add_argument("--ollama-urls", default=None,
                         help="Lista di endpoint Ollama separati da virgola, uno per GPU (es. "
                              "'http://localhost:11434/api/chat,http://localhost:11435/api/chat'). "
                              "I documenti di ogni domanda vengono smistati a rotazione fra tutti "
                              "gli endpoint indicati. Se impostato, ha la precedenza su --ollama-url.")
    parser.add_argument("--limit", type=int, default=None, help="Processa solo le prime N righe del file di input (default: tutte)")
    parser.add_argument("--delay", type=float, default=0.0, help="Secondi di pausa tra una chiamata e l'altra (default: 0)")
    parser.add_argument("--timeout", type=int, default=300, help="Timeout in secondi per ogni chiamata a Ollama (default: 300)")
    parser.add_argument("--keep-alive", default=DEFAULT_KEEP_ALIVE,
                         help="Per quanto tempo Ollama tiene il modello caricato in memoria fra una "
                              "chiamata e l'altra (default Ollama: 5m -> con pause piu' lunghe il "
                              "modello si ricarica da zero). Usa '-1' per tenerlo sempre caricato "
                              f"(default qui: {DEFAULT_KEEP_ALIVE})")
    parser.add_argument("--workers", type=int, default=DEFAULT_WORKERS,
                         help=f"Chiamate concorrenti a Ollama per domanda (default: {DEFAULT_WORKERS}). "
                              "Usa 1 per il comportamento sequenziale originale. Su GPU con VRAM "
                              "sufficiente il guadagno e' quasi lineare; su CPU puo' essere marginale "
                              "o nullo, dipende da quanti thread il calcolo puo' davvero usare")
    parser.add_argument("--no-skip-existing", action="store_true", help="Non saltare i claim gia' processati (riprocessa tutto)")
    parser.add_argument("--docs-per-question", type=int, default=DEFAULT_DOCS_PER_QUESTION,
                         help=f"Quanti documenti interrogare per ciascuna domanda (default: {DEFAULT_DOCS_PER_QUESTION})")
    parser.add_argument("--mapping", choices=["pooled", "strict"], default="pooled",
                         help="'pooled': ogni domanda viene confrontata con i documenti piu' pertinenti "
                              "fra TUTTI quelli scaricati per il claim (default). 'strict': solo i documenti "
                              "recuperati dalla query con lo stesso indice della domanda (comportamento storico)")
    parser.add_argument("--min-content-chars", type=int, default=DEFAULT_MIN_CONTENT_CHARS,
                         help=f"Scarta i documenti piu' corti di questa soglia, quasi sempre snippet di "
                              f"ranking anziche' articoli (default: {DEFAULT_MIN_CONTENT_CHARS})")
    parser.add_argument("--rollup-output", default=None,
                         help="Path del file riepilogativo con una riga per claim (default: "
                              "<output-dir>/rollup.jsonl). Conta gli esiti per domanda e per claim "
                              "senza combinarli in un verdetto unico: quella e' la Fase 5")
    parser.add_argument("--no-rollup", action="store_true",
                         help="Non generare il file riepilogativo")
    parser.add_argument("--time-budget-minutes", type=float, default=None,
                         help="Se impostato, lo script si ferma da solo (in modo pulito) dopo "
                              "questi minuti invece di farsi uccidere a meta' dal limite di "
                              "sessione della piattaforma. Il rollup viene comunque generato "
                              "su cio' che e' gia' su disco. Rilancia lo stesso comando per "
                              "riprendere: il resume salta i claim gia' processati.")
    args = parser.parse_args()

    if not args.turso_url or not args.turso_token:
        print("ERRORE: URL/token Turso mancanti. Passa --turso-url/--turso-token oppure imposta "
              "TURSO_DATABASE_URL/TURSO_AUTH_TOKEN.", file=sys.stderr)
        sys.exit(1)

    ollama_urls = [u.strip() for u in args.ollama_urls.split(",") if u.strip()] \
        if args.ollama_urls else [args.ollama_url]
    if len(ollama_urls) > 1:
        print(f"[INFO] distribuzione dei documenti su {len(ollama_urls)} endpoint Ollama: {ollama_urls}")

    claims = load_assertions(args.questions)
    os.makedirs(args.output_dir, exist_ok=True)

    claim_ids = list(claims.keys())
    if args.limit is not None:
        claim_ids = claim_ids[:args.limit]

    start_time = time.monotonic()
    stopped_early = False

    for i, claim_id in enumerate(claim_ids):
        if args.time_budget_minutes is not None and \
                (time.monotonic() - start_time) > args.time_budget_minutes * 60:
            stopped_early = True
            break
        claim_data = claims[claim_id]
        print(f"[{i}] id={claim_id} -> {claim_data['title']} ({len(claim_data['assertions'])} assertion)")
        process_claim(
            args.turso_url, args.turso_token, claim_id, claim_data, args.output_dir,
            model=args.model, ollama_urls=ollama_urls,
            delay=args.delay, skip_existing=not args.no_skip_existing, timeout=args.timeout,
            docs_per_question=args.docs_per_question, mapping=args.mapping,
            min_content_chars=args.min_content_chars, keep_alive=args.keep_alive,
            workers=args.workers,
        )

    if stopped_early:
        remaining = len(claim_ids) - i
        print(f"\n[TIME BUDGET] Limite di tempo raggiunto: {remaining} claim non ancora "
              f"processati. Rilancia lo stesso comando (Save & Run All) per riprendere da "
              f"dove si e' fermato.")

    if not args.no_rollup:
        rollup_path = args.rollup_output or os.path.join(args.output_dir, "rollup.jsonl")
        n = build_rollup(args.output_dir, claims, claim_ids, rollup_path)
        print(f"\nRiepilogo: {n} claim scritti in {rollup_path}")

    print("\nFatto.")


if __name__ == "__main__":
    main()
# Out:
# Overwriting /kaggle/working/4_blind_matching.py

# %% [markdown]
# ## 4. Controlla che gli input siano al loro posto
# Se questa cella non trova nulla di utile, ricontrolla i nomi dei Dataset aggiunti in Add Input.

# %%
# !ls -la /kaggle/input/
# !find /kaggle/input -maxdepth 4 -iname "*question*"
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Sep 22 16:21 .
# drwxr-xr-x 5 root root 4096 Sep 22 16:21 ..
# drwxr-xr-x 3 root root 4096 Sep 22 16:21 datasets
# /kaggle/input/datasets/silviatommaso/finalss/claims_with_questions.jsonl

# %%
# !rm -rf /kaggle/working/matching_results /kaggle/working/matching_results.zip

# %% [markdown]
# ## 4b. Recupera le credenziali Turso dai Secrets

# %%
import os
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
os.environ["TURSO_DATABASE_URL"] = user_secrets.get_secret("TURSO_DATABASE_URL")
os.environ["TURSO_AUTH_TOKEN"] = user_secrets.get_secret("TURSO_AUTH_TOKEN")
print("Turso URL caricato:", os.environ["TURSO_DATABASE_URL"])
# Out:
# Turso URL caricato: libsql://whatthefact-silvy.aws-eu-west-1.turso.io

# %% [markdown]
# ## 5. Esecuzione
# **Aggiorna `QUESTIONS_PATH` con il path reale mostrato sopra.**
#
# - `--ollama-urls`: i due endpoint (uno per GPU) avviati sopra — i documenti di ogni domanda vengono smistati a rotazione fra i due, cosi' entrambe le GPU lavorano davvero.
# - `--workers 8`: `NUM_PARALLEL_PER_GPU` (4) moltiplicato per il numero di GPU (2).
# - `--turso-url`/`--turso-token`: letti dai Secrets caricati sopra, non serve una cartella `sources/` come Dataset.
# - `--time-budget-minutes`: lo script smette di avviare nuovi claim dopo questo tempo invece di farsi uccidere a meta' dal limite di sessione Kaggle.

# %%
import os

QUESTIONS_PATH = "/kaggle/input/datasets/silviatommaso/finalss/claims_with_questions.jsonl"   # <-- aggiorna
OUTPUT_DIR = "/kaggle/working/matching_results"

os.makedirs(OUTPUT_DIR, exist_ok=True)

TIME_BUDGET_MINUTES = 120  # <-- 11h, con margine rispetto alle 12h massime di sessione GPU

# uno per GPU, nello stesso ordine di OLLAMA_INSTANCES (cella 4)
OLLAMA_URLS = ",".join(f"http://localhost:{inst['port']}/api/chat" for inst in OLLAMA_INSTANCES)

# !python /kaggle/working/4_blind_matching.py \
    --questions "{QUESTIONS_PATH}" \
    --output-dir "{OUTPUT_DIR}" \
    --turso-url "{os.environ['TURSO_DATABASE_URL']}" \
    --turso-token "{os.environ['TURSO_AUTH_TOKEN']}" \
    --model {MODEL} \
    --ollama-urls "{OLLAMA_URLS}" \
    --workers 8 \
    --keep-alive -1 \
    --time-budget-minutes {TIME_BUDGET_MINUTES}
# Out:
# [INFO] distribuzione dei documenti su 2 endpoint Ollama: ['http://localhost:11434/api/chat', 'http://localhost:11435/api/chat']
# [0] id=0 -> In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial. (2 assertion)
#   [INFO] 3 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   9 documenti utilizzabili nel pool del claim
#   domanda #1 (Who wrote a letter to Steve Jobs?...): 5 documenti selezionati
#     [1/5] https://politifact.com/factchecks/2020/oct/31/viral-image/fa (rilevanza 1.00) Fake Sean Connery letter to Steve Jobs spreads ...
#       -> Non verificabile
#     [2/5] https://www.cultofmac.com/news/no-sean-connery-didnt-turn-do (rilevanza 1.00) No, Sean Connery didn't turn down an offer from St
#       -> Concorda
#     [3/5] https://www.dtnext.in/sean-connery-never-wrote-a-rude-letter (rilevanza 1.00) Sean Connery never wrote a rude letter to Apple's
#       -> Contraddice
#     [4/5] https://www.imore.com/sean-connery-didnt-turn-down-chance-be (rilevanza 0.83) Sean Connery didn't turn down the chance to be in
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       [WARN] esito 'Non verificabile' ma il modello ha comunque estratto una risposta dall'articolo
#       -> Non verificabile [evidenza NON verificata]
#     [5/5] https://www.insidehook.com/culture/satirical-sean-connery-st (rilevanza 0.83) Debunked Sean Connery-Steve Jobs Letter Resurfaces
#       -> Non verificabile
#   domanda #2 (What was the subject of Sean Connery's letter to Steve Jobs?...): 5 documenti selezionati
#     [1/5] https://www.dtnext.in/sean-connery-never-wrote-a-rude-letter (rilevanza 0.94) Sean Connery never wrote a rude letter to Apple's
#       -> Contraddice
#     [2/5] https://www.imore.com/sean-connery-didnt-turn-down-chance-be (rilevanza 0.69) Sean Connery didn't turn down the chance to be in
#       -> Non verificabile
#     [3/5] https://www.reuters.com/article/world/fact-check-hoax-sean-c (rilevanza 0.56) Fact check: Hoax Sean Connery letter to Steve Jobs
#       -> Contraddice
#     [4/5] https://www.snopes.com/fact-check/false-sean-connery-letter- (rilevanza 0.56) Did Sean Connery Send a Letter to Apple Rejecting
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [5/5] https://www.thedrum.com/news/fake-sean-connery-letter-steve- (rilevanza 0.50) Fake Sean Connery letter to Steve Jobs leads to Tw
#       -> Contraddice
#   -> 10 matching salvati in /kaggle/working/matching_results/0.jsonl
# [1] id=1 -> Trump Administration claimed songwriter Billie Eilish Is Destroying Our Country In Leaked Documents (2 assertion)
#   [INFO] 2 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   10 documenti utilizzabili nel pool del claim
#   domanda #1 (What group claimed that Billie Eilish was destroying the cou...): 5 documenti selezionati
#     [1/5] https://www.washingtonexaminer.com/opinion/1757800/no-the-tr (rilevanza 0.92) No, the Trump administration did not claim Billie
#       -> Non verificabile
#     [2/5] https://www.complex.com/music/a/tracewilliamcowen/leaked-tru (rilevanza 0.83) Trump Administration Wrongly Quoted as Saying Bill
#       -> Concorda
#     [3/5] https://www.thefader.com/2020/10/29/report-trump-admin-docum (rilevanza 0.83) Report: Trump admin reached out to Billie Eilish f
#       -> Contraddice
#     [4/5] https://www.audacy.com/mix1051fm/music/alternative/trump-adm (rilevanza 0.83) Leaked Trump administration document says Billie E
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [5/5] https://www.gq.com.au/culture/entertainment/billie-eilish-is (rilevanza 0.83) Billie Eilish Is “Destroying Our Country” Claims L
#       -> Parzialmente concorda
#   domanda #2 (What form did the claim about Billie Eilish take?...): 5 documenti selezionati
#     [1/5] https://www.washingtonexaminer.com/opinion/1757800/no-the-tr (rilevanza 0.78) No, the Trump administration did not claim Billie
#       -> Contraddice
#     [2/5] https://www.youtube.com/watch?v=YZwtDJHA9uc (rilevanza 0.78) Billie Eilish DRAGGED By Leaked White House Docume
#       -> Contraddice
#     [3/5] https://www.stuff.co.nz/culture/350549166/trump-administrati (rilevanza 0.67) Trump administration accuses Billie Eilish of 'des
#       -> Contraddice
#     [4/5] https://www.gq.com.au/culture/entertainment/billie-eilish-is (rilevanza 0.67) Billie Eilish Is “Destroying Our Country” Claims L
#       -> Contraddice
#     [5/5] https://www.thefader.com/2020/10/29/report-trump-admin-docum (rilevanza 0.67) Report: Trump admin reached out to Billie Eilish f
#       -> Contraddice
#   -> 10 matching salvati in /kaggle/working/matching_results/1.jsonl
# [2] id=2 -> Due to Imran Khan's criticism of Macron's comments on Islam, French authorities cancelled the visas of 183 Pakistani citizens and deported 118 from the country. (2 assertion)
#   [INFO] 1 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   8 documenti utilizzabili nel pool del claim
#   domanda #1 (How many Pakistani citizens had their visas cancelled by Fre...): 5 documenti selezionati
#     [1/5] https://schengenvisainfo.com/news/fact-check-did-france-canc (rilevanza 1.00) Fact Check: Did France Cancel Visas of 183 Pakista
#       -> Concorda
#     [2/5] https://www.indiatoday.in/fact-check/story/fact-check-fake-t (rilevanza 1.00) Fact Check: Fake tweet on France deporting Pakista
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       [WARN] esito 'Non verificabile' ma il modello ha comunque estratto una risposta dall'articolo
#       -> Non verificabile [evidenza NON verificata]
#     [3/5] https://www.altnews.in/indian-media-outlets-fall-for-imposto (rilevanza 0.82) Indian media outlets fall for impostor account cla
#       -> Concorda
#     [4/5] https://www.geo.tv/latest/316317-fact-check-france-cancellat (rilevanza 0.82) Fact check: France did not deport Pakistanis after
#       -> Non verificabile
#     [5/5] https://www.opindia.com/2020/11/france-pakistan-visa-rejecte (rilevanza 0.82) Fact Check: No, France did not cancel visas of 183
#       -> Non verificabile
#   domanda #2 (How many Pakistani citizens were deported from France accord...): 5 documenti selezionati
#     [1/5] https://www.altnews.in/indian-media-outlets-fall-for-imposto (rilevanza 1.00) Indian media outlets fall for impostor account cla
#       -> Concorda
#     [2/5] https://www.youtube.com/watch?v=Ii50GqhYNEg (rilevanza 0.93) France Rejects 183 Pak Visitor Visas | Pakistan Co
#       -> Concorda
#     [3/5] https://schengenvisainfo.com/news/fact-check-did-france-canc (rilevanza 0.93) Fact Check: Did France Cancel Visas of 183 Pakista
#       -> Concorda
#     [4/5] https://www.geo.tv/latest/316317-fact-check-france-cancellat (rilevanza 0.93) Fact check: France did not deport Pakistanis after
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       [WARN] esito 'Non verificabile' ma il modello ha comunque estratto una risposta dall'articolo
#       -> Non verificabile [evidenza NON verificata]
#     [5/5] https://www.indiatoday.in/fact-check/story/fact-check-fake-t (rilevanza 0.93) Fact Check: Fake tweet on France deporting Pakista
#       -> Concorda
#   -> 10 matching salvati in /kaggle/working/matching_results/2.jsonl
# [3] id=3 -> UNESCO declared Nadar community as the most ancient race in the world. (1 assertion)
#   8 documenti utilizzabili nel pool del claim
#   domanda #1 (What did UNESCO declare about the Nadar community?...): 5 documenti selezionati
#     [1/5] https://www.vishvasnews.com/english/viral/fact-check-unesco- (rilevanza 1.00) Fact Check: UNESCO did not declare Nadar community
#       -> Contraddice
#     [2/5] https://www.eranielpalace.com/nadarHistory.php (rilevanza 0.69) nadar_history
#       -> Non verificabile
#     [3/5] https://www.sanrorhistoricalresearch.com/en/published-studie (rilevanza 0.54) From oblivion to light: Reconstructing Nadar commu
#       -> Non verificabile
#     [4/5] https://www.youtube.com/watch?v=SFvNPQPQw5s (rilevanza 0.54) Nadar History | History of Nadar Community | Tamil
#       -> Non verificabile
#     [5/5] https://www.indianetzone.com/nadar_caste (rilevanza 0.46) Nadar Caste
#       -> Non verificabile
#   -> 5 matching salvati in /kaggle/working/matching_results/3.jsonl
# [4] id=4 -> Republican Matt Gaetz was part of a company that had to pay 75 million in hospice fraud. They stole from dying people. (3 assertion)
#   [INFO] 2 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   14 documenti utilizzabili nel pool del claim
#   domanda #1 (How much did the company pay in hospice fraud?...): 5 documenti selezionati
#     [1/5] https://politifact.com/factchecks/2019/nov/01/facebook-posts (rilevanza 1.00) Post that says Florida Rep. Matt Gaetz has ‘numero
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#     [2/5] https://politifact.com/personalities/matt-gaetz (rilevanza 1.00) Matt Gaetz – PolitiFact
#       -> Non verificabile
#     [3/5] https://www.factcheck.org/2019/10/misleading-posts-target-go (rilevanza 1.00) Misleading Posts Target GOP Rep. Matt Gaetz - Fact
#       -> Concorda
#     [4/5] https://www.politifact.com/factchecks/2019/nov/01/facebook-p (rilevanza 1.00) Post that says Florida Rep. Matt Gaetz has ‘numero
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#     [5/5] https://x.com/bensiegel/status/1189586157560053760 (rilevanza 1.00) Ben Siegel on X: ".@RepMattGaetz says he's filing
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#   domanda #2 (What was the nature of the fraud?...): 5 documenti selezionati
#     [1/5] https://politifact.com/personalities/matt-gaetz (rilevanza 0.67) Matt Gaetz – PolitiFact
#       -> Non verificabile
#     [2/5] https://www.dailymail.com/news/article-9427673/Rep-Matt-Gaet (rilevanza 0.67) Rep. Matt Gaetz's father Don sold his hospice comp
#       -> Contraddice
#     [3/5] https://www.politifact.com/factchecks/2019/nov/01/facebook-p (rilevanza 0.67) Post that says Florida Rep. Matt Gaetz has ‘numero
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [4/5] https://politifact.com/factchecks/2019/nov/01/facebook-posts (rilevanza 0.67) Post that says Florida Rep. Matt Gaetz has ‘numero
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#     [5/5] https://www.factcheck.org/2019/10/misleading-posts-target-go (rilevanza 0.67) Misleading Posts Target GOP Rep. Matt Gaetz - Fact
#       -> Non verificabile
#   domanda #3 (Who was Matt Gaetz's political affiliation?...): 5 documenti selezionati
#     [1/5] https://www.govtrack.us/congress/members/matt_gaetz/412690 (rilevanza 0.73) Rep. Matt Gaetz [R-FL1, 2017-2024], former Represe
#       -> Concorda
#     [2/5] https://en.wikipedia.org/wiki/Matt_Gaetz (rilevanza 0.73) Matt Gaetz - Wikipedia
#       -> Concorda
#     [3/5] https://www.dailymail.com/news/article-9427673/Rep-Matt-Gaet (rilevanza 0.73) Rep. Matt Gaetz's father Don sold his hospice comp
#       -> Parzialmente concorda
#     [4/5] https://www.pbs.org/newshour/tag/matt-gaetz (rilevanza 0.64) Matt Gaetz | PBS News
#       -> Concorda
#     [5/5] https://politifact.com/factchecks/2019/nov/01/facebook-posts (rilevanza 0.45) Post that says Florida Rep. Matt Gaetz has ‘numero
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#   -> 15 matching salvati in /kaggle/working/matching_results/4.jsonl
# [5] id=5 -> The United States of America and its Western allies have been using their media outlets to publish articles based on fabricated information under allegations of non-compliance with the Chemical Weapons Convention. (3 assertion)
#   [INFO] 2 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   17 documenti utilizzabili nel pool del claim
#   domanda #1 (Which entities have been using their media outlets?...): 5 documenti selezionati
#     [1/5] https://archive.sana.sy/en?p=208083 (rilevanza 0.73) US, its allies use suspicious media outlets to def
#       -> Parzialmente concorda
#     [2/5] https://sana.sy/en?p=208083 (rilevanza 0.73) US, its allies use suspicious media outlets to def
#       -> Concorda
#     [3/5] https://www.facebook.com/sonja.vandenende/posts/the-united-s (rilevanza 0.73) The United States of America and its... - Sonja va
#       -> Concorda
#     [4/5] https://www.voanews.com/a/assad-regime-groundlessly-claims-u (rilevanza 0.73) Assad Regime Groundlessly Claims US and Allies are
#       -> Contraddice
#     [5/5] https://engelsbergideas.com/notebook/how-americas-allies-can (rilevanza 0.55) How America's allies can preserve the West - Engel
#       -> Contraddice
#   domanda #2 (What kind of information have they been publishing?...): 5 documenti selezionati
#     [1/5] https://archive.sana.sy/en?p=208083 (rilevanza 0.93) US, its allies use suspicious media outlets to def
#       -> Parzialmente concorda
#     [2/5] https://sana.sy/en?p=208083 (rilevanza 0.93) US, its allies use suspicious media outlets to def
#       -> Parzialmente concorda
#     [3/5] https://www.facebook.com/sonja.vandenende/posts/the-united-s (rilevanza 0.93) The United States of America and its... - Sonja va
#       -> Concorda
#     [4/5] https://www.voanews.com/a/assad-regime-groundlessly-claims-u (rilevanza 0.71) Assad Regime Groundlessly Claims US and Allies are
#       -> Concorda
#     [5/5] https://magazine.columbia.edu/article/are-we-really-all-suck (rilevanza 0.64) Are We Really All Suckers for Fake News? | Columbi
#       -> Non verificabile
#   domanda #3 (Under what allegations have these articles been published?...): 5 documenti selezionati
#     [1/5] https://www.voanews.com/a/assad-regime-groundlessly-claims-u (rilevanza 1.00) Assad Regime Groundlessly Claims US and Allies are
#       -> Parzialmente concorda
#     [2/5] https://2021-2025.state.gov/condition-10c-annual-report-on-c (rilevanza 0.84) Condition (10)(C) Annual Report on Compliance with
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#     [3/5] https://archive.sana.sy/en?p=208083 (rilevanza 0.84) US, its allies use suspicious media outlets to def
#       -> Concorda
#     [4/5] https://sana.sy/en?p=208083 (rilevanza 0.84) US, its allies use suspicious media outlets to def
#       -> Contraddice
#     [5/5] https://www.facebook.com/sonja.vandenende/posts/the-united-s (rilevanza 0.84) The United States of America and its... - Sonja va
#       -> Contraddice
#   -> 15 matching salvati in /kaggle/working/matching_results/5.jsonl
# [6] id=6 -> More than 225,000 people dead, 225,000. The estimates are, if we’d have acted responsibly, there’d be 160,000 fewer dead than there are today, because of covid-19. (2 assertion)
#   [INFO] 2 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   12 documenti utilizzabili nel pool del claim
#   domanda #1 (How many people are estimated to have died due to COVID-19?...): 5 documenti selezionati
#     [1/5] https://pmc.ncbi.nlm.nih.gov/articles/PMC9098098 (rilevanza 0.82) Exacerbation of COVID-19 mortality by the fragment
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [2/5] https://abcnews.com/Health/225000-americans-died-covid-19-st (rilevanza 0.64) Nearly 225,000 Americans have died of COVID-19 sin
#       -> Concorda
#     [3/5] https://inews.co.uk/news/nhs-ambulance-trusts-lost-working-d (rilevanza 0.64) NHS ambulance trusts lost 160,000 working days to
#       -> Non verificabile
#     [4/5] https://www.cidrap.umn.edu/covid-19/early-official-covid-dea (rilevanza 0.64) Early official COVID death tolls may have undercou
#       -> Contraddice
#     [5/5] https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_a (rilevanza 0.55) COVID-19 pandemic by country and territory
#       -> Contraddice
#   domanda #2 (What is the hypothetical number of deaths if responsible act...): 5 documenti selezionati
#     [1/5] https://abcnews.com/Health/225000-americans-died-covid-19-st (rilevanza 0.47) Nearly 225,000 Americans have died of COVID-19 sin
#       -> Non verificabile
#     [2/5] https://expose-news.com/2022/04/27/just-5115-people-died-cov (rilevanza 0.47) 160,000 COVID Deaths? – NHS confirms just 5,115 pe
#       -> Non verificabile
#     [3/5] https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_a (rilevanza 0.40) COVID-19 pandemic by country and territory
#       -> Non verificabile
#     [4/5] https://timmermanreport.com/2020/10/how-many-covid-19-deaths (rilevanza 0.33) How Many COVID-19 Deaths Could Have Been Avoided?
#       -> Concorda
#     [5/5] https://actuary.org/article/how-to-count (rilevanza 0.27) How to Count - Actuary.org
#       -> Non verificabile
#   -> 10 matching salvati in /kaggle/working/matching_results/6.jsonl
# [7] id=7 -> Why should you pay more taxes than Donald Trump pays? And that’s a fact. $750. Remember what he said when that was raised a while ago, how he only pays … He said, ‘Because I’m smart. I know how to game the system.’ (1 assertion)
#   [INFO] 3 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   7 documenti utilizzabili nel pool del claim
#   domanda #1 (How much did Donald Trump claim to pay in taxes?...): 5 documenti selezionati
#     [1/5] https://americasvoice.org/press_releases/experts-discuss-bil (rilevanza 0.82) Experts Discuss Billions In Taxes Paid By Immigran
#       -> Contraddice
#     [2/5] https://www.bbc.com/news/technology-54319948 (rilevanza 0.73) Donald Trump 'paid $750 in federal income taxes in
#       -> Contraddice
#     [3/5] https://taxfoundation.org/research/all/federal/details-analy (rilevanza 0.55) Donald Trump Tax Plan (2016)
#       -> Non verificabile
#     [4/5] https://www.bbc.com/news/world-us-canada-64127825 (rilevanza 0.55) Trump's tax returns reveal president's foreign ban
#       -> Contraddice
#     [5/5] https://en.wikipedia.org/wiki/Tax_returns_of_Donald_Trump (rilevanza 0.45) Tax returns of Donald Trump - Wikipedia
#       -> Non verificabile
#   -> 5 matching salvati in /kaggle/working/matching_results/7.jsonl
# [8] id=8 -> You’re watching the cheaters and all those people that send in the phony ballots. … They want to have the count weeks after November 3. (2 assertion)
#   [INFO] 4 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   10 documenti utilizzabili nel pool del claim
#   domanda #1 (What are the cheaters and phony ballots watching?...): 5 documenti selezionati
#     [1/5] https://www.youtube.com/watch?v=lmRcLmfBG7g (rilevanza 0.44) News 3 Now at Five: November 3, 2025
#       -> Non verificabile
#     [2/5] https://www.howtogeek.com/movies-to-watch-on-prime-video-thi (rilevanza 0.44) 5 Prime Video movies you have to watch this week (
#       -> Non verificabile
#     [3/5] https://www.youtube.com/watch?v=0p-_8cjoZgI (rilevanza 0.22) The Week of November 3rd, 2025: Big changes with a
#       -> Contraddice
#     [4/5] https://www.youtube.com/watch?v=Gbf__62JEYE (rilevanza 0.11) PBS News Hour full episode, Nov. 3, 2025
#       -> Non verificabile
#     [5/5] https://bipartisanpolicy.org/article/the-2026-midterms-key-d (rilevanza 0.11) The 2026 Midterms: Key Dates and Events
#       -> Non verificabile
#   domanda #2 (When do they want to have the count?...): 5 documenti selezionati
#     [1/5] https://bipartisanpolicy.org/article/the-2026-midterms-key-d (rilevanza 0.86) The 2026 Midterms: Key Dates and Events
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [2/5] https://failflow.com/weeksuntil/election-day (rilevanza 0.86) How Many Weeks Until Election Day 2026?
#       -> Contraddice
#     [3/5] https://www.youtube.com/watch?v=Gbf__62JEYE (rilevanza 0.86) PBS News Hour full episode, Nov. 3, 2025
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [4/5] https://community.whattoexpect.com/forums/november-2026-babi (rilevanza 0.71) Weeks calculator - November 2026 Babies | Forums |
#       -> Contraddice
#     [5/5] https://sonomacounty.gov/administrative-support-and-fiscal-s (rilevanza 0.71) November 3, 2026, General Election: Timeline | Reg
#       -> Contraddice
#   -> 10 matching salvati in /kaggle/working/matching_results/8.jsonl
# [9] id=9 -> You see the number today? 33.1 GDP. The biggest in the history of our country by almost triple, right? Almost triple. Now it’s very much bigger than any GDP we’ve ever had. You have to go back to the 1950s, and then it’s less than half. This is the greatest number, 33.1 percent. (2 assertion)
#   [INFO] 3 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   9 documenti utilizzabili nel pool del claim
#   domanda #1 (What is the claimed GDP percentage?...): 5 documenti selezionati
#     [1/5] https://www.bea.gov/news/2020/gross-domestic-product-third-q (rilevanza 0.88) Gross Domestic Product, Third Quarter 2020 (Advanc
#       -> Non verificabile
#     [2/5] https://www.nbcnews.com/business/economy/gdp-rose-33-1-perce (rilevanza 0.50) GDP rose at 33.1 percent annualized rate last quar
#       -> Concorda
#     [3/5] https://seekingalpha.com/article/4383190-u-s-q3-gdp-rises-33 (rilevanza 0.50) U.S. Q3 GDP Rises 33.1% - That's Our V Shaped Reco
#       -> Concorda
#     [4/5] https://trumpwhitehouse.archives.gov/articles/great-american (rilevanza 0.50) The Great American Recovery: Third Quarter GDP Blo
#       -> Contraddice
#     [5/5] https://www.macrotrends.net/global-metrics/countries/usa/uni (rilevanza 0.50) U.S. GDP Growth Rate (1961-2026) - Macrotrends
#       -> Contraddice
#   domanda #2 (How does the claim compare this GDP to previous records?...): 5 documenti selezionati
#     [1/5] https://www.cnbc.com/2020/10/29/us-gdp-report-third-quarter- (rilevanza 0.64) U.S. GDP booms at 33.1% rate in Q3 report, beating
#       -> Non verificabile
#     [2/5] https://www.foxbusiness.com/economy/us-economy-grew-by-recor (rilevanza 0.50) US economic growth shatters record at 33.1%, but f
#       -> Non verificabile
#     [3/5] https://www.nbcnews.com/business/economy/gdp-rose-33-1-perce (rilevanza 0.45) GDP rose at 33.1 percent annualized rate last quar
#       -> Non verificabile
#     [4/5] https://trumpwhitehouse.archives.gov/articles/great-american (rilevanza 0.36) The Great American Recovery: Third Quarter GDP Blo
#       -> Non verificabile
#     [5/5] https://seekingalpha.com/article/4383190-u-s-q3-gdp-rises-33 (rilevanza 0.32) U.S. Q3 GDP Rises 33.1% - That's Our V Shaped Reco
#       -> Non verificabile
#   -> 10 matching salvati in /kaggle/working/matching_results/9.jsonl
# [10] id=10 -> Donald Trump, when he thinks of climate change, he says hoax. Well, guess what? Speaking of hoaxes, remember what he said about these increasing violent hurricanes and the frequency? He actually said, maybe we should detonate a nuclear bomb over the Atlantic. By the way, the same stable genius who said the biggest problem we had in the Revolutionary War is we didn’t have enough airports. (3 assertion)
#   [INFO] 2 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   18 documenti utilizzabili nel pool del claim
#   domanda #1 (What does Donald Trump say about climate change?...): 5 documenti selezionati
#     [1/5] https://friendsoftheearth.uk/climate-change/donald-trump-stu (rilevanza 1.00) Donald Trump: stupid things he's said about the pl
#       -> Contraddice
#     [2/5] https://www.amnesty.org/en/latest/campaigns/2026/01/trump-im (rilevanza 1.00) How is US President Trump impacting global climate
#       -> Contraddice
#     [3/5] https://www.eenews.net/articles/con-scam-hoax-trumps-un-spee (rilevanza 1.00) 'Con,' 'scam,' 'hoax': Trump's UN speech on climat
#       -> Concorda
#     [4/5] https://www.irishstar.com/culture/entertainment/donald-trump (rilevanza 1.00) Donald Trump faces backlash from Fox News viewers
#       -> Concorda
#     [5/5] https://www.youtube.com/watch?v=38O2miFhrBM (rilevanza 1.00) Trump’s repeated dismissal of climate change as a
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#   domanda #2 (What did Donald Trump suggest about hurricanes?...): 5 documenti selezionati
#     [1/5] https://www.newsweek.com/fact-check-did-donald-trump-suggest (rilevanza 0.81) Fact-Check: Did Donald Trump Suggest Nuking Hurric
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#     [2/5] https://www.eenews.net/articles/can-trump-nuke-a-hurricane-n (rilevanza 0.69) Can Trump nuke a hurricane? No one could stop him,
#       -> Concorda
#     [3/5] https://www.bbc.com/news/world-us-canada-49471093 (rilevanza 0.62) Nuclear weapons and hurricanes don't mix, NOAA adv
#       -> Concorda
#     [4/5] https://www.courthousenews.com/trump-denies-report-he-wanted (rilevanza 0.50) Trump Denies Report He Wanted to Nuke Hurricanes |
#       -> Concorda
#     [5/5] https://en.wikipedia.org/wiki/Nuclear_strikes_on_hurricanes (rilevanza 0.44) Nuclear strikes on hurricanes - Wikipedia
#       -> Concorda
#   domanda #3 (What did Donald Trump say about the Revolutionary War?...): 5 documenti selezionati
#     [retry 1/3] chiamata Ollama fallita: 500 Server Error: Internal Server Error for url: http://localhost:11434/api/chat
#     [1/5] https://time.com/5620936/donald-trump-revolutionary-war-airp (rilevanza 0.77) Trump Says Revolutionary War Troops 'Took Over the
#       -> Contraddice
#     [2/5] https://www.scarymommy.com/trump-revolutionary-airports-reac (rilevanza 0.77) Trump Said Airports Existed During The Revolutiona
#       -> Contraddice
#     [3/5] https://www.bbc.com/news/blogs-trending-48880867 (rilevanza 0.69) Donald Trump's 'airport' revolution sees people re
#       -> Contraddice
#     [4/5] https://www.fox5dc.com/news/in-fourth-of-july-speech-trump-p (rilevanza 0.69) In Fourth of July speech, Trump praises Revolution
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [5/5] https://www.nbcnews.com/politics/donald-trump/trump-blames-t (rilevanza 0.69) Trump blames teleprompter for Revolutionary War 'a
#       -> Contraddice
#   -> 15 matching salvati in /kaggle/working/matching_results/10.jsonl
# [11] id=11 -> The U.S. surgeon general and the Centers for Disease Control both previously said that ‘masks are not effective in preventing [the] general public from catching coronavirus.’ (1 assertion)
#   [INFO] 1 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   9 documenti utilizzabili nel pool del claim
#   domanda #1 (What did the U.S. surgeon general and the Centers for Diseas...): 5 documenti selezionati
#     [1/5] https://en.wikipedia.org/wiki/Face_masks_during_the_COVID-19 (rilevanza 0.86) Face masks during the COVID-19 pandemic in the Uni
#       -> Contraddice
#     [2/5] https://time.com/5794729/coronavirus-face-masks (rilevanza 0.86) Why People Aren't Listening to Experts About Face
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#     [3/5] https://www.cnbc.com/2020/04/02/coronavirus-us-surgeon-gener (rilevanza 0.86) Coronavirus: US surgeon general asks CDC to see if
#       -> Concorda
#     [4/5] https://www.rt.com/op-ed/530567-cdc-fauci-covid-mask-guidanc (rilevanza 0.86) Masks off? Or masks on? A history of the CDC’s con
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Concorda [evidenza NON verificata]
#     [5/5] https://www.nytimes.com/2020/02/29/health/coronavirus-n95-fa (rilevanza 0.73) Surgeon General Urges the Public to Stop Buying Fa
#       -> Contraddice
#   -> 5 matching salvati in /kaggle/working/matching_results/11.jsonl
# [12] id=12 -> New Zealand’s new Food Bill bans gardening (1 assertion)
#   [INFO] 1 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   7 documenti utilizzabili nel pool del claim
#   domanda #1 (What does the source report about the new Food Bill ban gard...): 5 documenti selezionati
#     [1/5] https://thespinoff.co.nz/media/18-06-2016/new-zealands-absur (rilevanza 0.82) New Zealand's absurd gardening ban once again make
#       -> Non verificabile
#     [2/5] https://alannairving.medium.com/3-facts-about-new-zealand-i- (rilevanza 0.82) Medium
#       -> Contraddice
#     [3/5] https://en.wikipedia.org/wiki/Gardening_in_New_Zealand (rilevanza 0.64) Gardening in New Zealand - Wikipedia
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       [WARN] esito 'Non verificabile' ma il modello ha comunque estratto una risposta dall'articolo
#       -> Non verificabile [evidenza NON verificata]
#     [4/5] https://www.aap.com.au/factcheck/new-zealands-new-food-bill- (rilevanza 0.64) New Zealand's 'new' Food Bill doesn't ban gardenin
#       -> Contraddice
#     [5/5] https://www.themiddlesizedgarden.co.uk/where-is-gardening-il (rilevanza 0.55) Where is gardening illegal?
#       -> Non verificabile
#   -> 5 matching salvati in /kaggle/working/matching_results/12.jsonl
# [13] id=13 -> Wearing face masks will stop the spread of covid 19 (1 assertion)
#   [INFO] 1 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   9 documenti utilizzabili nel pool del claim
#   domanda #1 (What is the claim about?...): 5 documenti selezionati
#     [1/5] https://www.epa.gov/emergency-response-research/evaluating-e (rilevanza 0.86) Evaluating the Effectiveness of Facial Coverings a
#       -> Contraddice
#     [2/5] https://thepeoplesvoice.tv/wearing-womens-tights-over-face-m (rilevanza 0.86) Wearing Womens Tights Over Face Mask Helps Stop Co
#       -> Contraddice
#     [3/5] https://journals.asm.org/doi/10.1128/msphere.00637-20 (rilevanza 0.71) Effectiveness of Face Masks in Preventing Airborne
#       -> Parzialmente concorda
#     [4/5] https://www.mayoclinic.org/diseases-conditions/coronavirus/i (rilevanza 0.71) How well do face masks protect against COVID-19?
#       -> Non verificabile
#     [5/5] https://www.mdpi.com/1660-4601/22/10/1590 (rilevanza 0.71) Evidence of Face Masks and Masking Policies for th
#       -> Contraddice
#   -> 5 matching salvati in /kaggle/working/matching_results/13.jsonl
# [14] id=14 -> Jammu and Kashmir (J&K) in Pakistan/India was removed from the United Nations (UN) list of “unresolved disputes”. (1 assertion)
#   [INFO] 1 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   9 documenti utilizzabili nel pool del claim
#   domanda #1 (What was removed from the United Nations list of ‘unresolved...): 5 documenti selezionati
#     [1/5] https://factly.in/old-news-of-jk-removal-from-uns-alleged-di (rilevanza 1.00) Old news of removal of J&K from UN’s alleged ‘disp
#       -> Non verificabile
#     [2/5] https://www.altnews.in/old-unfounded-reports-of-removal-of-j (rilevanza 1.00) Old unfounded reports of removal of JK from UN ‘li
#       -> Non verificabile
#     [3/5] https://www.boomlive.in/fake-news/has-the-un-removed-kashmir (rilevanza 1.00) Has The UN Removed Kashmir From Unresolved Dispute
#       -> Concorda
#     [4/5] https://www.rediff.com/news/interview/kashmir-removed-from-u (rilevanza 1.00) Kashmir removed from UN list of disputes - Rediff.
#       -> Parzialmente concorda
#     [5/5] https://en.wikipedia.org/wiki/Azad_Kashmir (rilevanza 0.50) Azad Kashmir - Wikipedia
#       -> Non verificabile
#   -> 5 matching salvati in /kaggle/working/matching_results/14.jsonl
# [15] id=15 -> Illegal drug, border crossings, and human smuggling activities have decreased in areas where barriers are deployed in the United States. (3 assertion)
#   10 documenti utilizzabili nel pool del claim
#   domanda #1 (What does the source report about illegal drug activities de...): 5 documenti selezionati
#     [1/5] https://irp.fas.org/offdocs/iccs/iccsiv.html (rilevanza 0.59) International Crime Control Strategy, Chapter 4
#       -> Non verificabile
#     [2/5] https://2009-2017.state.gov/j/inl/c/crime/c44640.htm (rilevanza 0.35) Border Security/Alien Smuggling
#       -> Non verificabile
#     [3/5] https://www.ice.gov/features/human-smuggling-danger (rilevanza 0.35) Archived: Human smuggling equals grave danger, big
#       -> Non verificabile
#     [4/5] https://www.bea.gov/news/glance (rilevanza 0.29) U.S. Economy at a Glance
#       -> Non verificabile
#     [5/5] https://www.census.gov/newsroom/press-releases/2026/populati (rilevanza 0.18) U.S. Population Growth Slows Due to Historic Decli
#       -> Non verificabile
#   domanda #2 (What does the source report about border crossings activitie...): 5 documenti selezionati
#     [1/5] https://irp.fas.org/offdocs/iccs/iccsiv.html (rilevanza 0.63) International Crime Control Strategy, Chapter 4
#       -> Non verificabile
#     [2/5] https://2009-2017.state.gov/j/inl/c/crime/c44640.htm (rilevanza 0.32) Border Security/Alien Smuggling
#       -> Non verificabile
#     [3/5] https://www.ice.gov/features/human-smuggling-danger (rilevanza 0.32) Archived: Human smuggling equals grave danger, big
#       -> Non verificabile
#     [4/5] https://www.tandfonline.com/doi/full/10.1080/09636412.2021.1 (rilevanza 0.32) Channeling Contraband: How States Shape Internatio
#       -> Contraddice
#     [5/5] https://www.bea.gov/news/glance (rilevanza 0.26) U.S. Economy at a Glance
#       -> Non verificabile
#   domanda #3 (What does the source report about human smuggling activities...): 5 documenti selezionati
#     [1/5] https://irp.fas.org/offdocs/iccs/iccsiv.html (rilevanza 0.58) International Crime Control Strategy, Chapter 4
#       -> Non verificabile
#     [2/5] https://www.ice.gov/features/human-smuggling-danger (rilevanza 0.47) Archived: Human smuggling equals grave danger, big
#       -> Non verificabile
#     [3/5] https://2009-2017.state.gov/j/inl/c/crime/c44640.htm (rilevanza 0.42) Border Security/Alien Smuggling
#       -> Non verificabile
#     [4/5] https://www.bea.gov/news/glance (rilevanza 0.26) U.S. Economy at a Glance
#       -> Non verificabile
#     [5/5] https://www.tandfonline.com/doi/full/10.1080/09636412.2021.1 (rilevanza 0.26) Channeling Contraband: How States Shape Internatio
#       -> Contraddice
#   -> 15 matching salvati in /kaggle/working/matching_results/15.jsonl
# [16] id=16 -> The plentiful evidence we have indicates that masks would not meaningfully help with aerosol transmission of COVID 19. (1 assertion)
#   9 documenti utilizzabili nel pool del claim
#   domanda #1 (What does the claim state about masks and aerosol transmissi...): 5 documenti selezionati
#     [1/5] https://journals.asm.org/doi/10.1128/msphere.00637-20 (rilevanza 0.58) Effectiveness of Face Masks in Preventing Airborne
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [2/5] https://www.nature.com/articles/s41598-020-72798-7 (rilevanza 0.58) Efficacy of masks and face coverings in controllin
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [3/5] https://www.cidrap.umn.edu/covid-19/commentary-covid-19-tran (rilevanza 0.58) COMMENTARY: COVID-19 transmission messages should
#       -> Contraddice
#     [4/5] https://www.science.org/doi/10.1126/science.abd9149 (rilevanza 0.50) Airborne transmission of respiratory viruses
#       -> Contraddice
#     [5/5] https://www.nationalnursesunited.org/sites/default/files/nnu (rilevanza 0.50) CDC's Recognition of Aerosol Transmission of Covid
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#   -> 5 matching salvati in /kaggle/working/matching_results/16.jsonl
# [17] id=17 -> All USA Ballots Arriving After Election Day Will Be Thrown Out (1 assertion)
#   [INFO] 2 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   8 documenti utilizzabili nel pool del claim
#   domanda #1 (What will happen to ballots arriving after Election Day?...): 5 documenti selezionati
#     [1/5] https://www.usatoday.com/story/news/factcheck/2020/10/30/fac (rilevanza 0.92) Fact check: Some mail-in ballots arriving post-Ele
#       -> Contraddice
#     [2/5] https://www.theguardian.com/us-news/2026/jun/29/supreme-cour (rilevanza 0.92) US supreme court upholds law to count mail-in ball
#       -> Contraddice
#     [3/5] http://www.guardian.co.uk/us-news/2026/jun/29/supreme-court- (rilevanza 0.75) US supreme court upholds law to count mail-in ball
#       -> Contraddice
#     [4/5] https://www.dailysignal.com/2026/06/29/high-court-rules-on-m (rilevanza 0.75) High Court Rules on Mail Ballots Arriving After El
#       -> Contraddice
#     [5/5] https://news.lee.net/mail-in-ballots-after-election-day-supr (rilevanza 0.58) Mail-in ballots after Election Day? Supreme Court
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#   -> 5 matching salvati in /kaggle/working/matching_results/17.jsonl
# [18] id=18 -> Even if your mail-in ballot is postmarked prior to the Election day but arrives after the Election day it will be thrown out. (1 assertion)
#   10 documenti utilizzabili nel pool del claim
#   domanda #1 (What will happen to a mail-in ballot postmarked before Elect...): 5 documenti selezionati
#     [1/5] https://vote.upenn.edu/vote-by-mail (rilevanza 0.76) Vote By Mail | Penn Leads the Vote
#       -> Concorda
#     [2/5] https://www.bbc.com/news/articles/c93629rzpgxo (rilevanza 0.76) Supreme Court allows late-arriving mail-in ballots
#       -> Contraddice
#     [3/5] https://fairelectionscenter.org/postal-service-changes-and-m (rilevanza 0.71) Postal Service Changes and Mail Voting
#       -> Concorda
#     [4/5] https://www.nj.gov/state/elections/vote-by-mail.shtml (rilevanza 0.71) NJ DOS - Division of Elections - Vote-By-Mail
#       -> Contraddice
#     [5/5] https://dailydot.com/usps-postmark-change (rilevanza 0.71) "Of all the dirty tricks": USPS quietly changed wh
#       -> Contraddice
#   -> 5 matching salvati in /kaggle/working/matching_results/18.jsonl
# [19] id=19 -> Video shows attack of French embassy in Sudan (1 assertion)
#   7 documenti utilizzabili nel pool del claim
#   domanda #1 (What does the video show?...): 5 documenti selezionati
#     [1/5] https://factcheck.afp.com/video-shows-protesters-storming-ge (rilevanza 1.00) This video shows protesters storming the German em
#       -> Contraddice
#     [2/5] https://www.boomlive.in/fake-news/2012-embassy-attacks-in-su (rilevanza 1.00) 2012 Embassy Attacks In Sudan Falsely Shared As At
#       -> Contraddice
#     [3/5] https://www.altnews.in/fact-check-did-muslims-in-sudan-attac (rilevanza 0.83) Old video falsely viral as Muslims set ablaze Fren
#       -> Contraddice
#     [4/5] https://factly.in/old-video-is-being-passed-off-as-french-em (rilevanza 0.67) Old video is being passed off as French embassy se
#       -> Contraddice
#     [5/5] https://www.mtv.com.lb/en/News/Politics/1358626/french-natio (rilevanza 0.67) French national was injured in air attack in Sudan
#       -> Non verificabile
#   -> 5 matching salvati in /kaggle/working/matching_results/19.jsonl
# [20] id=20 -> Viral video purportedly shows Pakistani opposition MPs chanted ‘Modi, Modi’ (India's PM)  inside the Pakistani Parliament (1 assertion)
#   10 documenti utilizzabili nel pool del claim
#   domanda #1 (What did Pakistani opposition MPs allegedly chant in the Par...): 5 documenti selezionati
#     [1/5] https://www.boomlive.in/amp/fact-check/world/viral-video-pak (rilevanza 0.80) Russia-Ukraine Conflict: No, Pakistani MPs Did Not
#       -> Contraddice
#     [2/5] https://www.boomlive.in/fact-check/world/viral-video-pakista (rilevanza 0.80) Russia-Ukraine Conflict: No, Pakistani MPs Did Not
#       -> Contraddice
#     [3/5] https://www.indiatoday.in/amp/fact-check/story/fact-check-di (rilevanza 0.80) Fact Check: Did Pakistan MPs chant ‘Modi, Modi’ in
#       -> Contraddice
#     [4/5] https://www.indiatoday.in/fact-check/story/fact-check-did-pa (rilevanza 0.80) Fact Check: Did Pakistan MPs chant ‘Modi, Modi’ in
#       -> Contraddice
#     [5/5] https://timesofindia.indiatimes.com/times-fact-check/news/fa (rilevanza 0.67) FACT CHECK: Were ‘Modi-Modi’ chants raised inside
#       -> Contraddice
#   -> 5 matching salvati in /kaggle/working/matching_results/20.jsonl
# [21] id=21 -> Taylor Zundel claimed on Instagram that she and other early voters in Utah, were unable to cast ballots in the 2020 presidential elections, as they were told they had already voted. (2 assertion)
#   [INFO] 4 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   7 documenti utilizzabili nel pool del claim
#   domanda #1 (What platform did Taylor Zundel claim the issue occurred on?...): 5 documenti selezionati
#     [1/5] https://www.factcheck.org/2020/11/video-doesnt-show-voter-fr (rilevanza 0.38) Video Doesn't Show Voter Fraud in Utah - FactCheck
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Contraddice [evidenza NON verificata]
#     [2/5] https://law.justia.com/cases/utah/court-of-appeals-published (rilevanza 0.31) Zundel v. Ramsdell (Utah Ct. App. 2024)
#       -> Non verificabile
#     [3/5] https://huggingface.co/datasets/s-nlp/AVeriTeC_dev_filtered_ (rilevanza 0.31) s-nlp/AVeriTeC_dev_filtered_10shot · Datasets at H
#       -> Non verificabile
#     [4/5] https://www.instagram.com/p/CDzZqyfhv8a (rilevanza 0.23) 4 years with this goddess ❤️ I love you Tay - Inst
#       -> Non verificabile
#     [5/5] https://linkedin.com/in/taylor-zundel-69978052 (rilevanza 0.15) Taylor Zundel - BA in Communications - National Ma
#       -> Non verificabile
#   domanda #2 (What specific issue did Taylor Zundel claim occurred for ear...): 5 documenti selezionati
#     [1/5] https://www.factcheck.org/2020/11/video-doesnt-show-voter-fr (rilevanza 0.54) Video Doesn't Show Voter Fraud in Utah - FactCheck
#       -> Contraddice
#     [2/5] https://huggingface.co/datasets/s-nlp/AVeriTeC_dev_filtered_ (rilevanza 0.39) s-nlp/AVeriTeC_dev_filtered_10shot · Datasets at H
#       -> Non verificabile
#     [3/5] https://law.justia.com/cases/utah/court-of-appeals-published (rilevanza 0.25) Zundel v. Ramsdell (Utah Ct. App. 2024)
#       -> Non verificabile
#     [4/5] https://linkedin.com/in/taylor-zundel-69978052 (rilevanza 0.21) Taylor Zundel - BA in Communications - National Ma
#       -> Non verificabile
#     [5/5] https://www.linkedin.com/in/taylor-zundel-realtor (rilevanza 0.18) Taylor Dixon Zundel, Realtor(R) - Real Estate Agen
#       -> Non verificabile
#   -> 10 matching salvati in /kaggle/working/matching_results/21.jsonl
# [22] id=22 -> Trash Can Plastered With 'Ballot Box' Sign In Philadelphia Was Intended To Get People To Toss Their Ballots In The Trash. (2 assertion)
#   [INFO] 4 documenti scartati perche' senza contenuto sufficiente (< 500 caratteri)
#   6 documenti utilizzabili nel pool del claim
#   domanda #1 (What was plastered on the trash can in Philadelphia?...): 5 documenti selezionati
#     [retry 1/3] chiamata Ollama fallita: 500 Server Error: Internal Server Error for url: http://localhost:11435/api/chat
#     [retry 1/3] chiamata Ollama fallita: 500 Server Error: Internal Server Error for url: http://localhost:11434/api/chat
#     [retry 1/3] chiamata Ollama fallita: 500 Server Error: Internal Server Error for url: http://localhost:11435/api/chat
#     [1/5] https://www.reuters.com/article/uk-factcheck-ballot-box-sign (rilevanza 1.00) Fact check: ‘Ballot box’ signs on trash cans were
#       -> Concorda
#     [2/5] https://leadstories.com/hoax-alert/2020/10/fact-check-a-work (rilevanza 1.00) Fact Check: Trash Can Plastered With 'Ballot Box'
#       -> Contraddice
#     [3/5] https://api.politifact.com/factchecks/2020/oct/28/instagram- (rilevanza 0.91) PolitiFact | Ad for history exhibit in Philadelphi
#       -> Contraddice
#     [4/5] https://www.politifact.com/factchecks/2020/oct/28/instagram- (rilevanza 0.91) Ad for history exhibit in Philadelphia is mistaken
#       -> Contraddice
#     [5/5] https://politifact.com/factchecks/2020/oct/28/instagram-post (rilevanza 0.91) Ad for history exhibit in Philadelphia is mistaken
#       -> Contraddice
#   domanda #2 (What was the intended action for people regarding their ball...): 5 documenti selezionati
#     [1/5] https://api.politifact.com/factchecks/2020/oct/28/instagram- (rilevanza 0.64) PolitiFact | Ad for history exhibit in Philadelphi
#       -> Non verificabile
#     [2/5] https://leadstories.com/hoax-alert/2020/10/fact-check-a-work (rilevanza 0.64) Fact Check: Trash Can Plastered With 'Ballot Box'
#       -> Non verificabile
#     [3/5] https://politifact.com/factchecks/2020/oct/28/instagram-post (rilevanza 0.64) Ad for history exhibit in Philadelphia is mistaken
#       -> Contraddice
#     [4/5] https://www.politifact.com/factchecks/2020/oct/28/instagram- (rilevanza 0.64) Ad for history exhibit in Philadelphia is mistaken
#       -> Non verificabile
#     [5/5] https://www.ktvu.com/news/trash-cans-in-california-town-of-c (rilevanza 0.27) Trash cans in California town of Crockett littered
#       -> Non verificabile
#   -> 10 matching salvati in /kaggle/working/matching_results/22.jsonl
# [23] id=23 -> Joe Biden wants to ban fracking (1 assertion)
#   7 documenti utilizzabili nel pool del claim
#   domanda #1 (What does Joe Biden want to ban?...): 5 documenti selezionati
#     [1/5] https://politifact.com/truth-o-meter/promises/biden-promise- (rilevanza 1.00) Joe Biden takes first step toward ban on new frack
#       -> Parzialmente concorda
#     [2/5] https://www.cbsnews.com/news/kamala-harris-biden-administrat (rilevanza 1.00) Harris defends Biden's climate plan, says his admi
#       -> Non verificabile
#     [3/5] https://www.eenews.net/articles/biden-couldnt-ban-fracking-e (rilevanza 1.00) Biden couldn't ban fracking even if he tried - E&E
#       -> Contraddice
#     [4/5] https://earth.org/bidens-fracking-ban (rilevanza 0.86) Biden Fracking Ban At A Standstill Amid Global Ene
#       [WARN] evidenza restituita dal modello NON trovata verbatim nel testo (possibile hallucination)
#       -> Parzialmente concorda [evidenza NON verificata]
#     [5/5] https://www.cnn.com/2021/01/27/business/fracking-ban-biden-f (rilevanza 0.86) No, Joe Biden didn’t just ban fracking | CNN Busin
#       -> Contraddice
#   -> 5 matching salvati in /kaggle/working/matching_results/23.jsonl
# [24] id=24 -> Germany’s Foreign Minister Heiko Maas said that Thailand’s King Maha Vajiralongkorn didn’t do anything illegal while at his German residence. (1 assertion)
#   8 documenti utilizzabili nel pool del claim
#   domanda #1 (What did Germany’s Foreign Minister Heiko Maas say about Tha...): 5 documenti selezionati
#     [1/5] https://clubofmozambique.com/news/unusual-if-not-illegal-ger (rilevanza 0.73) Unusual, if not 'illegal': Germany says Thai king
#       -> Contraddice
#     [2/5] https://www.latimes.com/world-nation/story/2020-10-16/thaila (rilevanza 0.73) Thailand king faces protests at home, legal questi
#       -> Contraddice
#     [3/5] https://royalcentral.co.uk/asia/thailand/german-foreign-mini (rilevanza 0.53) German foreign minister against Thai king reigning
#       -> Contraddice
# ...
#   [WARN] nessun documento utilizzabile per il claim 423 nel DB, salto
# [424] id=424 -> Voters in North Carolina can send their Mail-in vote and then go to the polling place to vote again to check that their mail-in vote has been counted. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 424 nel DB, salto
# [425] id=425 -> Fox News is unavailable in Canada because the Radio Act makes it a crime to lie to the public via airwaves. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 425 nel DB, salto
# [426] id=426 -> "Jihadists" attacked a Temple in West Bengal and charred the Hindu deity Kali (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 426 nel DB, salto
# [427] id=427 -> U.S. citizens should show up at polling places on Election Day and cast an in-person ballot if poll workers can’t confirm that their mail-in ballot was received. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 427 nel DB, salto
# [428] id=428 -> More cops have died from COVID this year than have been killed on patrol. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 428 nel DB, salto
# [429] id=429 -> A Pakistani website was hacked by an Indian cyber group to wish Pawan Kalyan a Happy Birthday. (3 assertion)
#   [WARN] nessun documento utilizzabile per il claim 429 nel DB, salto
# [430] id=430 -> US President Trump opened a complaint platform to report censorship on Facebook, Twitter and YouTube. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 430 nel DB, salto
# [431] id=431 -> US President Trump issued an executive order for the White House to take over all electrical grids, which will include internet servers, broadcasting systems and electronic systems (6 assertion)
#   [WARN] nessun documento utilizzabile per il claim 431 nel DB, salto
# [432] id=432 -> US President Trump canceled the Democrats’ HR6666 bill, known as the COVID-19 TRACE Act. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 432 nel DB, salto
# [433] id=433 -> US President Trump canceled Bill Gates’ project known as ID2020 (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 433 nel DB, salto
# [434] id=434 -> US President Trump issued an executive order to reopen states in lockdown during COVID-19 pandemic; governors who refuse will be sued (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 434 nel DB, salto
# [435] id=435 -> Igbo people In Nigeria (Igbo people are found in southeastern Nigeria) are the richest people per capita in Africa. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 435 nel DB, salto
# [436] id=436 -> The US military will check purity and distribute COVID-19 vaccines in US. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 436 nel DB, salto
# [437] id=437 -> A 21 year old can have sex with an 11-year-old, and not be listed on the sex registry as a sex offender (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 437 nel DB, salto
# [438] id=438 -> In Massachusetts, "anybody can go vote for anybody so long as they have their information. … They're not even checking IDs at the polling stations." (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 438 nel DB, salto
# [439] id=439 -> Economic damage caused by the pandemic shows United States GDP (gross domestic product) falling by 33 percent compared to India's 23.9 percent drop. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 439 nel DB, salto
# [440] id=440 -> In Belfast, the digital sector employs 26 per cent of the workforce. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 440 nel DB, salto
# [441] id=441 -> Hooligans from the Muslim community were behind the desecration of Goddess Kali Idol in a Bengal Temple in West Bengal's Murshidabad district by burning it. (4 assertion)
#   [WARN] nessun documento utilizzabile per il claim 441 nel DB, salto
# [442] id=442 -> Bill Gates was involved in crafting the TRACE Act. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 442 nel DB, salto
# [443] id=443 -> It's NOT a SECOND WAVE of COVID-19 coming soon. It's the NORMAL COLD / FLU SEASON (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 443 nel DB, salto
# [444] id=444 -> The World Health Organization (WHO) says there is no proof that face masks protect against Covid-19. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 444 nel DB, salto
# [445] id=445 -> Masks lower immune systems. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 445 nel DB, salto
# [446] id=446 -> US President Trump made vaccines voluntary, not mandatory, in the US. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 446 nel DB, salto
# [447] id=447 -> A virus can easily pass through a mask. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 447 nel DB, salto
# [448] id=448 -> Kyle Rittenhouse failed to appear at his court hearing in Lake County, Illinois, on 28th August 2020 and was given an extra month to comply. (3 assertion)
#   [WARN] nessun documento utilizzabile per il claim 448 nel DB, salto
# [449] id=449 -> Some US mayors are fining people for going to church during the COVID-19 pandemic. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 449 nel DB, salto
# [450] id=450 -> US President Trump declared places of worship as essential services during COVID-19 pandemic. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 450 nel DB, salto
# [451] id=451 -> PEDOPHILIA is now LEGAL in CALIFORNIA (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 451 nel DB, salto
# [452] id=452 -> Republican Maine Sen. Susan Collins said of President Donald Trump, “Yes, I said that I wouldn’t endorse him but that doesn’t mean I don’t fully support him.” (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 452 nel DB, salto
# [453] id=453 -> US President Trump instructed his administration to halt funding of the World Health Organization while a review was conducted to assess the World Health Organization’s role regarding the spread of coronavirus. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 453 nel DB, salto
# [454] id=454 -> Face masks cause hypoxia. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 454 nel DB, salto
# [455] id=455 -> US Cable news channel Fox News is unavailable in Canada due to media legislation. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 455 nel DB, salto
# [456] id=456 -> idol of goddess Kali was burnt in West bengals Murshidabad by the muslim community. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 456 nel DB, salto
# [457] id=457 -> The Radio Act in Canada makes it a crime to lie to the public via airwaves. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 457 nel DB, salto
# [458] id=458 -> The South African Police Service kills three times more people per capita than the United States police force (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 458 nel DB, salto
# [459] id=459 -> In 2018, South African police service officers were accused of 217 cases of torture and 3,661 cases of assault. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 459 nel DB, salto
# [460] id=460 -> Since 2002, South Africa’s police force has grown by 50%. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 460 nel DB, salto
# [461] id=461 -> All India Institute of Medical Sciences Nursing Officer Recruitment Common Eligibility Test 2020 was postponed. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 461 nel DB, salto
# [462] id=462 -> US cable news channel Fox News is not available in Canada due to media legislation in the country. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 462 nel DB, salto
# [463] id=463 -> 558 people were killed by the police in 2018, while 201 people died in police custody (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 463 nel DB, salto
# [464] id=464 -> The number of North American bison has been reduced to only twenty-seven individuals due to colonizers. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 464 nel DB, salto
# [465] id=465 -> Jacob Blake raped a 14 year old teenage girl. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 465 nel DB, salto
# [466] id=466 -> Amber Alert Issued For License Plate Q72B381 (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 466 nel DB, salto
# [467] id=467 -> Suresh Raina, the Chennai Super Kings (CSK) cricketer, has withdrawn from the upcoming 2020 edition of the IPL after testing positive for COVID-19. (3 assertion)
#   [WARN] nessun documento utilizzabile per il claim 467 nel DB, salto
# [468] id=468 -> Even with a voter ID card, you won’t be allowed to vote in Ghana on December 7 if your name is not found in the Register. So, people should take advantage of the exhibition exercise to verify their names. (3 assertion)
#   [WARN] nessun documento utilizzabile per il claim 468 nel DB, salto
# [469] id=469 -> A crowdfunding campaign on the Christian site GiveSendGo solicited donations to help Kyle Rittenhouse, a 17-year-old accused of killing two people at a protest in Kenosha, Wisconsin. (5 assertion)
#   [WARN] nessun documento utilizzabile per il claim 469 nel DB, salto
# [470] id=470 -> Islamic study is a subject in UPSC exam (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 470 nel DB, salto
# [471] id=471 -> The Trump RNC Acceptance Speech Was The First Time The White House Was Used For 'Purely Political Campaign Event' (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 471 nel DB, salto
# [472] id=472 -> Donald trump said "We have already built 300 miles of border wall." (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 472 nel DB, salto
# [473] id=473 -> Donald Trump says Biden "is even talking about taking the wall down." (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 473 nel DB, salto
# [474] id=474 -> George Floyd died of drug overdose, not US police brutality (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 474 nel DB, salto
# [475] id=475 -> Donald Trump said: Biden "has pledged a $4 trillion tax hike on almost all American families." (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 475 nel DB, salto
# [476] id=476 -> Biden has promised to abolish the production of American oil, coal, shale, and natural gas. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 476 nel DB, salto
# [477] id=477 -> Joe Biden had not condemned the violence and looting during protests in Kenosha, Wisconsin by 27th August 2020 (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 477 nel DB, salto
# [478] id=478 -> Duterte has signed order to open nuclear power plant. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 478 nel DB, salto
# [479] id=479 -> Donald Trump said "When the anarchists started ripping down our statues and monuments, right outside, I signed an order immediately, 10 years in prison." (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 479 nel DB, salto
# [480] id=480 -> Donald Trump said: "Biden also vowed to oppose school choice and close down charter schools, ripping away the ladder of opportunity for Black and Hispanic children." (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 480 nel DB, salto
# [481] id=481 -> Donald Trump said: "When asked if he supports cutting police funding, Joe Biden replied, ‘Yes, absolutely.’" (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 481 nel DB, salto
# [482] id=482 -> Donald trump said: "Joe Biden recently raised his hand on the debate stage and promised he was going to give it away, your health care dollars to illegal immigrants, which is going to bring massive number of immigrants into our country." (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 482 nel DB, salto
# [483] id=483 -> Donald Trump said "We have spent nearly $2.5 trillion on completely rebuilding our military, which was very badly depleted when I took office." (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 483 nel DB, salto
# [484] id=484 -> The Edo State government of Nigeria receives 600 million naira monthly as a security vote. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 484 nel DB, salto
# [485] id=485 -> Donald Trump said "Last month, I took on Big Pharma. You think that is easy? I signed orders that would massively lower the cost of your prescription drugs." (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 485 nel DB, salto
# [486] id=486 -> President Trump marshalled the full resources of our federal government to deal with the coronavirus from the outset. He directed the US to forge a seamless partnership with governors across America in both political parties. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 486 nel DB, salto
# [487] id=487 -> Kyle Rittenhouse, shooter in the Kenosha shootings, was a white supremacist. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 487 nel DB, salto
# [488] id=488 -> Mobs torched our cities while popular members of Congress promote the same socialism my father fought against in World War II. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 488 nel DB, salto
# [489] id=489 -> Kenosha police allowed Kyle Rittenhouse to walk away after he killed two protesters and injured a third with an AR-15-style rifle. (4 assertion)
#   [WARN] nessun documento utilizzabile per il claim 489 nel DB, salto
# [490] id=490 -> EU Trade Commissioner resigned after being accused of violating COVID-19 health rules in Ireland (3 assertion)
#   [WARN] nessun documento utilizzabile per il claim 490 nel DB, salto
# [491] id=491 -> Joe Biden wants to end school choice. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 491 nel DB, salto
# [492] id=492 -> Where President Donald Trump achieved energy independence for the United States, Joe Biden would abolish fossil fuels and end fracking. (3 assertion)
#   [WARN] nessun documento utilizzabile per il claim 492 nel DB, salto
# [493] id=493 -> Before the first case of the coronavirus spread within the United States, the president Donald Trump took unprecedented action and suspended all travel from China. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 493 nel DB, salto
# [494] id=494 -> The Obama-Biden administration secretly launched a surveillance operation on the Trump campaign. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 494 nel DB, salto
# [495] id=495 -> This Democratic Party of Joe Biden is pushing the so-called Green New Deal. If given power, they would essentially ban animal agriculture and eliminate gas-powered cars. (4 assertion)
#   [WARN] nessun documento utilizzabile per il claim 495 nel DB, salto
# [496] id=496 -> Joe Biden is for open borders, sanctuary cities, free lawyers and health care for illegal immigrants. (4 assertion)
#   [WARN] nessun documento utilizzabile per il claim 496 nel DB, salto
# [497] id=497 -> Nancy Pelosi says that China would prefer Joe Biden. (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 497 nel DB, salto
# [498] id=498 -> As we speak the US are developing a growing number of treatments, including convalescent plasma, that are saving lives all across the country. (2 assertion)
#   [WARN] nessun documento utilizzabile per il claim 498 nel DB, salto
# [499] id=499 -> The first night of the US Republican National Convention had 128.4 million viewers (1 assertion)
#   [WARN] nessun documento utilizzabile per il claim 499 nel DB, salto
#
# Riepilogo: 136 claim scritti in /kaggle/working/matching_results/rollup.jsonl
#
# Fatto.

# %% [markdown]
# ## 6. Comprimi i risultati per scaricarli
# Il file zip compare nella tab **Output** del notebook (pannello a destra) a fine sessione, oppure lo scarichi subito da qui.

# %%
# !zip -r /kaggle/working/matching_results.zip /kaggle/working/matching_results
# Out:
#   adding: kaggle/working/matching_results/ (stored 0%)
#   adding: kaggle/working/matching_results/40.jsonl (deflated 87%)
#   adding: kaggle/working/matching_results/132.jsonl (deflated 71%)
#   adding: kaggle/working/matching_results/18.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/69.jsonl (deflated 78%)
#   adding: kaggle/working/matching_results/82.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/122.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/9.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/19.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/67.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/117.jsonl (deflated 86%)
#   adding: kaggle/working/matching_results/89.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/119.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/103.jsonl (deflated 83%)
#   adding: kaggle/working/matching_results/125.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/116.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/102.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/36.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/39.jsonl (deflated 71%)
#   adding: kaggle/working/matching_results/32.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/130.jsonl (deflated 84%)
#   adding: kaggle/working/matching_results/43.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/88.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/83.jsonl (deflated 70%)
#   adding: kaggle/working/matching_results/87.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/45.jsonl (deflated 78%)
#   adding: kaggle/working/matching_results/4.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/25.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/131.jsonl (deflated 77%)
#   adding: kaggle/working/matching_results/24.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/91.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/106.jsonl (deflated 88%)
#   adding: kaggle/working/matching_results/62.jsonl (deflated 77%)
#   adding: kaggle/working/matching_results/55.jsonl (deflated 69%)
#   adding: kaggle/working/matching_results/42.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/46.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/124.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/97.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/12.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/95.jsonl (deflated 85%)
#   adding: kaggle/working/matching_results/35.jsonl (deflated 70%)
#   adding: kaggle/working/matching_results/51.jsonl (deflated 78%)
#   adding: kaggle/working/matching_results/94.jsonl (deflated 82%)
#   adding: kaggle/working/matching_results/73.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/10.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/7.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/129.jsonl (deflated 86%)
#   adding: kaggle/working/matching_results/127.jsonl (deflated 71%)
#   adding: kaggle/working/matching_results/93.jsonl (deflated 83%)
#   adding: kaggle/working/matching_results/20.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/81.jsonl (deflated 86%)
#   adding: kaggle/working/matching_results/107.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/86.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/64.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/113.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/71.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/1.jsonl (deflated 78%)
#   adding: kaggle/working/matching_results/15.jsonl (deflated 89%)
#   adding: kaggle/working/matching_results/26.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/34.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/84.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/76.jsonl (deflated 84%)
#   adding: kaggle/working/matching_results/114.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/53.jsonl (deflated 78%)
#   adding: kaggle/working/matching_results/59.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/128.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/134.jsonl (deflated 77%)
#   adding: kaggle/working/matching_results/133.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/70.jsonl (deflated 83%)
#   adding: kaggle/working/matching_results/6.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/104.jsonl (deflated 82%)
#   adding: kaggle/working/matching_results/78.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/rollup.jsonl (deflated 85%)
#   adding: kaggle/working/matching_results/75.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/118.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/111.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/54.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/41.jsonl (deflated 85%)
#   adding: kaggle/working/matching_results/110.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/29.jsonl (deflated 84%)
#   adding: kaggle/working/matching_results/56.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/120.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/80.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/101.jsonl (deflated 84%)
#   adding: kaggle/working/matching_results/11.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/8.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/90.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/48.jsonl (deflated 68%)
#   adding: kaggle/working/matching_results/112.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/100.jsonl (deflated 84%)
#   adding: kaggle/working/matching_results/109.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/44.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/58.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/61.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/66.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/85.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/14.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/33.jsonl (deflated 84%)
#   adding: kaggle/working/matching_results/99.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/37.jsonl (deflated 83%)
#   adding: kaggle/working/matching_results/38.jsonl (deflated 71%)
#   adding: kaggle/working/matching_results/98.jsonl (deflated 71%)
#   adding: kaggle/working/matching_results/30.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/77.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/16.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/60.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/126.jsonl (deflated 73%)
#   adding: kaggle/working/matching_results/23.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/72.jsonl (deflated 82%)
#   adding: kaggle/working/matching_results/68.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/27.jsonl (deflated 82%)
#   adding: kaggle/working/matching_results/92.jsonl (deflated 84%)
#   adding: kaggle/working/matching_results/2.jsonl (deflated 83%)
#   adding: kaggle/working/matching_results/17.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/74.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/28.jsonl (deflated 83%)
#   adding: kaggle/working/matching_results/50.jsonl (deflated 77%)
#   adding: kaggle/working/matching_results/96.jsonl (deflated 88%)
#   adding: kaggle/working/matching_results/65.jsonl (deflated 78%)
#   adding: kaggle/working/matching_results/5.jsonl (deflated 85%)
#   adding: kaggle/working/matching_results/22.jsonl (deflated 82%)
#   adding: kaggle/working/matching_results/0.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/49.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/108.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/79.jsonl (deflated 74%)
#   adding: kaggle/working/matching_results/57.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/105.jsonl (deflated 77%)
#   adding: kaggle/working/matching_results/63.jsonl (deflated 79%)
#   adding: kaggle/working/matching_results/135.jsonl (deflated 72%)
#   adding: kaggle/working/matching_results/115.jsonl (deflated 76%)
#   adding: kaggle/working/matching_results/31.jsonl (deflated 77%)
#   adding: kaggle/working/matching_results/123.jsonl (deflated 80%)
#   adding: kaggle/working/matching_results/21.jsonl (deflated 82%)
#   adding: kaggle/working/matching_results/52.jsonl (deflated 81%)
#   adding: kaggle/working/matching_results/121.jsonl (deflated 75%)
#   adding: kaggle/working/matching_results/47.jsonl (deflated 68%)
#   adding: kaggle/working/matching_results/13.jsonl (deflated 71%)
#   adding: kaggle/working/matching_results/3.jsonl (deflated 79%)
